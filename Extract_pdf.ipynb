# %%
import os
import PyPDF2
import pandas as pd

''' Extracting all the contents from the pdf'''

def extract_pdf_content(pdf_folder):
    # Create an empty DataFrame to store the data
    pdf_data = pd.DataFrame(columns=['pdf_name', 'pdf_content'])

    # Loop through the PDF files in the folder
    for pdf_file in os.listdir(pdf_folder):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            pdf_content = extract_text_from_pdf(pdf_path)
            pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)

    return pdf_data

def extract_text_from_pdf(pdf_file):
    text = ''
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)
    for page_num in range(pdf_reader.numPages):
        page = pdf_reader.getPage(page_num)
        text += page.extractText()
    return text

# Path to the folder containing PDF files
pdf_folder = 'dataset'

# Call the function to extract PDF content and get the DataFrame
pdf_data = extract_pdf_content(pdf_folder)

pdf_data
# Out:
# C:\Users\sitas\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\sitas\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
# C:\Users\sitas\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\.libs\libopenblas64__v0.3.23-246-g3d31191b-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
# C:\Users\sitas\AppData\Local\Temp\ipykernel_8312\3915116966.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pdf_data = pdf_data.append({'pdf_name': pdf_file, 'pdf_content': pdf_content}, ignore_index=True)
#                                              pdf_name  \
# 0                                            0670.pdf
# 1                   1-s2.0-S1877050921022365-main.pdf
# 2                   1-s2.0-S1877050923006099-main.pdf
# 3                                      2302.01713.pdf
# 4                                      2304.01062.pdf
# 5                               978-1-4842-9253-2.pdf
# 6                             978-3-031-12423-5_7.pdf
# 7                               978-3-031-36118-0.pdf
# 8                             978-3-031-39847-6_1.pdf
# 9                            978-3-031-45021-1_23.pdf
# 10                                           A3-2.pdf
# 11           AComparativeStudyofDataArchitectures.pdf
# 12  Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 13  CowMesh_a_data-mesh_architecture_to_unify_dair...
# 14                         data-mesh-icws23-paper.pdf
# 15  Data_Mesh_a_Systematic_Gray_Literature_Review.pdf
# 16  Data_Mesh_Motivational_Factors_Challenges_and_...
# 17  Decentralized_Data_Governance_as_Part_of_a_Dat...
# 18                   Diplomityo_Vinnikainen_Oskar.pdf
# 19  Enterprise_Data_Strategy_A_Decentralized_Data_...
# 20  Finding_Your_Way_Through_the_Jungle_of_Big_Dat...
# 21                        IJARCCE.2023.124121v2.0.pdf
# 22         majorchallengesinimplementingadatamesh.pdf
# 23  Navigating_the_Data_Architecture_Landscape_A_C...
# 24  Numerical Meth Engineering - 1998 - BEALL - A ...
# 25                          SKILL_2022_paper_8188.pdf
# 26                        urn_nbn_fi_uef-20211359.pdf
#
#                                           pdf_content
# 0    \n Introducing Data Mesh paradigm for Smart C...
# 1   ScienceDirect\nAvailable online at www.science...
# 2   ScienceDirect\nAvailable online at www.science...
# 3   Data Mesh: Best Practices to Avoid the Data Me...
# 4   Data Mesh: a Systematic Gray Literature Review...
# 5   Data Fabric and Data \nMesh Approaches  with A...
# 6   CoK: A Survey of Privacy Challenges\nin Relati...
# 7   Lecture Notes on Data Engineering\nand Communi...
# 8   Data Integration Revitalized: From Data\nWareh...
# 9   Converging Data Mesh and Microservice\nPrincip...
# 10   \n Identifying Alternatives and Deciding Fact...
# 11  A Comparative Study of Data Architectures: Azu...
# 12  XXX -X-XXXX -XXXX -X/XX/$XX.00 ©20XX IEEE  Bre...
# 13  TYPEMethods\nPUBLISHED /zero.tnum/four.tnum Oc...
# 14  See discussions, st ats, and author pr ofiles ...
# 15  Data Mesh: a Systematic Gray Literature Review...
# 16  Data Mesh: Motivational Factors, Challenges, a...
# 17   Decentralized Data Governance as Part of a \n...
# 18   \n \n \n \n \n \n \n \nDATA MESH : A HOLISTIC...
# 19  Enterprise Data Strategy: A Decentralized Data...
# 20  2021 IEEE International Conference on Big Data...
# 21  See discussions, st ats, and author pr ofiles ...
# 22  See discussions, st ats, and author pr ofiles ...
# 23  Review Not peer-reviewed version\nNavigating t...
# 24  INTERNATIONAL JOURNAL FOR NUMERICAL METHODS IN...
# 25   \n Identifying Alternatives and Deciding Fact...
# 26        \n  \n \nUtilization  of Data Mesh Frame...

# %%
csv_filename = 'Data_mesh_csv.csv'

# Save the DataFrame to a CSV file
pdf_data.to_csv(csv_filename, index=False)
