# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import altair as alt
import os
import re

import numpy as np
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('Data_mesh_cleaned.csv')
df
# Out:
#                                              Filename  \
# 0   Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 1   Decentralized_Data_Governance_as_Part_of_a_Dat...
# 2   Enterprise_Data_Strategy_A_Decentralized_Data_...
# 3   Finding_Your_Way_Through_the_Jungle_of_Big_Dat...
# 4                                 978-1-4842-9253-2_1
# 5                                978-1-4842-9253-2_10
# 6                                978-1-4842-9253-2_11
# 7                                978-1-4842-9253-2_12
# 8                                978-1-4842-9253-2_13
# 9                                978-1-4842-9253-2_14
# 10                               978-1-4842-9253-2_15
# 11                               978-1-4842-9253-2_16
# 12                               978-1-4842-9253-2_17
# 13                                978-1-4842-9253-2_2
# 14                                978-1-4842-9253-2_3
# 15                                978-1-4842-9253-2_4
# 16                                978-1-4842-9253-2_5
# 17                                978-1-4842-9253-2_6
# 18                                978-1-4842-9253-2_7
# 19                                978-1-4842-9253-2_8
# 20                                978-1-4842-9253-2_9
# 21                                978-3-031-12423-5_7
# 22                                  978-3-031-36118-0
# 23                                978-3-031-39847-6_1
# 24                               978-3-031-45021-1_23
# 25               AComparativeStudyofDataArchitectures
# 26  CowMesh_a_data-mesh_architecture_to_unify_dair...
# 27                             data-mesh-icws23-paper
# 28      Data_Mesh_a_Systematic_Gray_Literature_Review
# 29  Data_Mesh_Motivational_Factors_Challenges_and_...
# 30                            IJARCCE.2023.124121v2.0
# 31             majorchallengesinimplementingadatamesh
# 32  Navigating_the_Data_Architecture_Landscape_A_C...
# 33                              SKILL_2022_paper_8188
# 34                              SKILL_2022_paper_8188
# 35                                               0670
# 36                      1-s2.0-S1877050921022365-main
# 37                                         2302.01713
# 38                                               A3-2
# 39                       Diplomityo_Vinnikainen_Oskar
# 40                            urn_nbn_fi_uef-20211359
#
#                                               Content      Publisher
# 0   chieve effective aggregation data localization...           IEEE
# 1   pproaches arif wider sumedha verma atif akhtar...           IEEE
# 2   decentralized data vijay kumar butte sujata bu...           IEEE
# 3   rchitectures torsten priebe sebastian neumaier...           IEEE
# 4   look back data architecture developed response...       Springer
# 5   provide high overview data fabric data evoluti...       Springer
# 6   saw data fabric architecture evolution previou...       Springer
# 7   look intersection two initiative digital trans...       Springer
# 8   metadata digital era enterprise know aspect da...       Springer
# 9   applying ai metadata intelligent cataloging da...       Springer
# 10  data constantly generated live data incredible...       Springer
# 11  goal data fabric provide flexible seamless aut...       Springer
# 12  must become obvious book unified data fabric a...       Springer
# 13  term data fabric data often viewed different c...       Springer
# 14  organization realized importance implementing ...       Springer
# 15  defining data fabric underlying data architect...       Springer
# 16  introduces key capability concept knowledge ca...       Springer
# 17  ai ml dl broadly speaking ai simulate human pe...       Springer
# 18  today data rich enterprise frequently confront...       Springer
# 19  data describe core entity referred master data...       Springer
# 20  ai lifecycle ai software engineering fundament...       Springer
# 21  dealing data privacy perspective important ind...       Springer
# 22  day amount collected stored processed analyzed...       Springer
# 23  data integration area active already six decad...       Springer
# 24  advent convergence operating technology ot inf...       Springer
# 25  digital age quantity data produced globally gr...   ResearchGate
# 26  dairy industry experiencing strong global grow...   ResearchGate
# 27  data socio technical decentralized analytics d...   ResearchGate
# 28  world living golden age data idc data corporat...   ResearchGate
# 29  volume data continues grow organization strivi...   ResearchGate
# 30  technology advance data volume velocity increa...   ResearchGate
# 31  major challenge implementing data cultural shi...   ResearchGate
# 32  dynamic world data machine learning foundation...   ResearchGate
# 33  world importance data continuously grows choos...   ResearchGate
# 34  vailable author program chair procs author pro...       Elsevier
# 35  definition smart city coexist together single ...  miscellaneous
# 36  inherent growing varied form software applicat...  miscellaneous
# 37  volume data continues grow organization strivi...  miscellaneous
# 38  world importance data continuously grows choos...  miscellaneous
# 39  today live world important asset data accordin...  miscellaneous
# 40  digital technology present almost every consum...  miscellaneous

# %%
# def generate_custom_token_pattern(ngram_min, ngram_max):
#     # Ensure no word repetition in n-grams
#     word_pattern = r'\b(\w+)\b(?=.*\b\1\b)'
    
#     # Combine word patterns for specified n-gram range
#     ngram_pattern = r'(?:' + word_pattern + r'\s){' + str(ngram_min - 1) + r',' + str(ngram_max - 1) + r'}' + word_pattern
    
#     return ngram_pattern

# token_pattern = generate_custom_token_pattern(1, 4)

# %%
def extract_topics(text, tfidf_vectorizer, lda_model):
    
    # TF-IDF Vectorization for the specific document
    tfidf_data = tfidf_vectorizer.transform([text])
    tfidf_values = tfidf_data.toarray()
    feature_names = np.array(tfidf_vectorizer.get_feature_names_out())
    df_tfidf = pd.DataFrame(data=tfidf_values, columns=feature_names)

    # Apply LDA
    doc_topic_prob = lda_model.transform(tfidf_data)

    # Get the most probable topic for the document
    most_probable_topic = np.argmax(doc_topic_prob)

    # Get the top words for the most probable topic with TF-IDF values
    topic = lda_model.components_[most_probable_topic]
    top_keywords_idx = topic.argsort()[:-10 - 1:-1]
    top_keywords = [feature_names[i] for i in top_keywords_idx]
    top_tfidf_values = [tfidf_vectorizer.idf_[tfidf_vectorizer.vocabulary_[word]] for word in top_keywords]
    topic_words = list(zip(top_keywords, top_tfidf_values))

    return most_probable_topic + 1, topic_words

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(1, 4), token_pattern=r'\b\w+\b')
tfidf_data = tfidf_vectorizer.fit_transform(df['Content'])

# Apply LDA
lda = LatentDirichletAllocation(n_components=20, random_state=42)
lda.fit(tfidf_data)

# Assuming 'df' is your DataFrame with 'pdf_content' column
df['topic'], df['topic_words'] = zip(*df.apply(lambda row: extract_topics(row['Content'], tfidf_vectorizer, lda), axis=1))

# %%
df
# Out:
#                                              Filename  \
# 0   Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 1   Decentralized_Data_Governance_as_Part_of_a_Dat...
# 2   Enterprise_Data_Strategy_A_Decentralized_Data_...
# 3   Finding_Your_Way_Through_the_Jungle_of_Big_Dat...
# 4                                 978-1-4842-9253-2_1
# 5                                978-1-4842-9253-2_10
# 6                                978-1-4842-9253-2_11
# 7                                978-1-4842-9253-2_12
# 8                                978-1-4842-9253-2_13
# 9                                978-1-4842-9253-2_14
# 10                               978-1-4842-9253-2_15
# 11                               978-1-4842-9253-2_16
# 12                               978-1-4842-9253-2_17
# 13                                978-1-4842-9253-2_2
# 14                                978-1-4842-9253-2_3
# 15                                978-1-4842-9253-2_4
# 16                                978-1-4842-9253-2_5
# 17                                978-1-4842-9253-2_6
# 18                                978-1-4842-9253-2_7
# 19                                978-1-4842-9253-2_8
# 20                                978-1-4842-9253-2_9
# 21                                978-3-031-12423-5_7
# 22                                  978-3-031-36118-0
# 23                                978-3-031-39847-6_1
# 24                               978-3-031-45021-1_23
# 25               AComparativeStudyofDataArchitectures
# 26  CowMesh_a_data-mesh_architecture_to_unify_dair...
# 27                             data-mesh-icws23-paper
# 28      Data_Mesh_a_Systematic_Gray_Literature_Review
# 29  Data_Mesh_Motivational_Factors_Challenges_and_...
# 30                            IJARCCE.2023.124121v2.0
# 31             majorchallengesinimplementingadatamesh
# 32  Navigating_the_Data_Architecture_Landscape_A_C...
# 33                              SKILL_2022_paper_8188
# 34                              SKILL_2022_paper_8188
# 35                                               0670
# 36                      1-s2.0-S1877050921022365-main
# 37                                         2302.01713
# 38                                               A3-2
# 39                       Diplomityo_Vinnikainen_Oskar
# 40                            urn_nbn_fi_uef-20211359
#
#                                               Content      Publisher  topic  \
# 0   chieve effective aggregation data localization...           IEEE     10
# 1   pproaches arif wider sumedha verma atif akhtar...           IEEE     17
# 2   decentralized data vijay kumar butte sujata bu...           IEEE      9
# 3   rchitectures torsten priebe sebastian neumaier...           IEEE      2
# 4   look back data architecture developed response...       Springer      1
# 5   provide high overview data fabric data evoluti...       Springer     11
# 6   saw data fabric architecture evolution previou...       Springer      9
# 7   look intersection two initiative digital trans...       Springer     16
# 8   metadata digital era enterprise know aspect da...       Springer     11
# 9   applying ai metadata intelligent cataloging da...       Springer      8
# 10  data constantly generated live data incredible...       Springer     12
# 11  goal data fabric provide flexible seamless aut...       Springer     15
# 12  must become obvious book unified data fabric a...       Springer     18
# 13  term data fabric data often viewed different c...       Springer     10
# 14  organization realized importance implementing ...       Springer      8
# 15  defining data fabric underlying data architect...       Springer      6
# 16  introduces key capability concept knowledge ca...       Springer      8
# 17  ai ml dl broadly speaking ai simulate human pe...       Springer     13
# 18  today data rich enterprise frequently confront...       Springer      1
# 19  data describe core entity referred master data...       Springer      2
# 20  ai lifecycle ai software engineering fundament...       Springer     10
# 21  dealing data privacy perspective important ind...       Springer      5
# 22  day amount collected stored processed analyzed...       Springer      8
# 23  data integration area active already six decad...       Springer     11
# 24  advent convergence operating technology ot inf...       Springer      1
# 25  digital age quantity data produced globally gr...   ResearchGate     12
# 26  dairy industry experiencing strong global grow...   ResearchGate      4
# 27  data socio technical decentralized analytics d...   ResearchGate     17
# 28  world living golden age data idc data corporat...   ResearchGate     11
# 29  volume data continues grow organization strivi...   ResearchGate     19
# 30  technology advance data volume velocity increa...   ResearchGate      8
# 31  major challenge implementing data cultural shi...   ResearchGate     19
# 32  dynamic world data machine learning foundation...   ResearchGate      1
# 33  world importance data continuously grows choos...   ResearchGate      9
# 34  vailable author program chair procs author pro...       Elsevier     12
# 35  definition smart city coexist together single ...  miscellaneous     17
# 36  inherent growing varied form software applicat...  miscellaneous      3
# 37  volume data continues grow organization strivi...  miscellaneous     19
# 38  world importance data continuously grows choos...  miscellaneous      9
# 39  today live world important asset data accordin...  miscellaneous     10
# 40  digital technology present almost every consum...  miscellaneous     15
#
#                                           topic_words
# 0   [(localization, 4.044522437723423), (data loca...
# 1   [(port, 2.6582280766035327), (city, 2.65822807...
# 2   [(principle, 1.5187937934151674), (paper, 1.69...
# 3   [(logical data warehouse, 3.6390573296152584),...
# 4   [(dwh, 3.128231705849268), (edw, 3.12823170584...
# 5   [(id, 2.9459101490553135), (intelligent catalo...
# 6   [(principle, 1.5187937934151674), (paper, 1.69...
# 7   [(hybrid cloud, 2.791759469228055), (hybrid, 2...
# 8   [(id, 2.9459101490553135), (intelligent catalo...
# 9   [(data, 1.0), (product, 1.1267517056391438), (...
# 10  [(smart monitoring, 4.044522437723423), (smart...
# 11  [(microsoft, 2.791759469228055), (vendor offer...
# 12  [(ontology, 2.9459101490553135), (rdf, 4.04452...
# 13  [(localization, 4.044522437723423), (data loca...
# 14  [(data, 1.0), (product, 1.1267517056391438), (...
# 15  [(driver, 2.6582280766035327), (key driver, 3....
# 16  [(data, 1.0), (product, 1.1267517056391438), (...
# 17  [(ml dl concept, 4.044522437723423), (relevant...
# 18  [(dwh, 3.128231705849268), (edw, 3.12823170584...
# 19  [(logical data warehouse, 3.6390573296152584),...
# 20  [(localization, 4.044522437723423), (data loca...
# 21  [(anonymisation, 4.044522437723423), (identi, ...
# 22  [(data, 1.0), (product, 1.1267517056391438), (...
# 23  [(id, 2.9459101490553135), (intelligent catalo...
# 24  [(dwh, 3.128231705849268), (edw, 3.12823170584...
# 25  [(smart monitoring, 4.044522437723423), (smart...
# 26  [(dairy, 4.044522437723423), (farm, 4.04452243...
# 27  [(port, 2.6582280766035327), (city, 2.65822807...
# 28  [(id, 2.9459101490553135), (intelligent catalo...
# 29  [(interviewee, 3.128231705849268), (bp, 3.6390...
# 30  [(data, 1.0), (product, 1.1267517056391438), (...
# 31  [(interviewee, 3.128231705849268), (bp, 3.6390...
# 32  [(dwh, 3.128231705849268), (edw, 3.12823170584...
# 33  [(principle, 1.5187937934151674), (paper, 1.69...
# 34  [(smart monitoring, 4.044522437723423), (smart...
# 35  [(port, 2.6582280766035327), (city, 2.65822807...
# 36  [(big data, 1.793230639116928), (possible conc...
# 37  [(interviewee, 3.128231705849268), (bp, 3.6390...
# 38  [(principle, 1.5187937934151674), (paper, 1.69...
# 39  [(localization, 4.044522437723423), (data loca...
# 40  [(microsoft, 2.791759469228055), (vendor offer...

# %%
result_data = []

# Iterate through each row in the original DataFrame
for _, row in df.iterrows():
    Filename = row['Filename']
    topic_words = row['topic_words']

    # Iterate through each tuple in the list of topic_words
    for word, idf_value in topic_words:
        result_data.append({'Filename': Filename, 'topic_word': word, 'idf_value': idf_value})

# Create the result DataFrame from the list
result_df = pd.DataFrame(result_data, columns=['Filename', 'topic_word', 'idf_value'])

# Print the result DataFrame
result_df
# Out:
#                                               Filename  \
# 0    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 1    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 2    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 3    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 4    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# ..                                                 ...
# 405                            urn_nbn_fi_uef-20211359
# 406                            urn_nbn_fi_uef-20211359
# 407                            urn_nbn_fi_uef-20211359
# 408                            urn_nbn_fi_uef-20211359
# 409                            urn_nbn_fi_uef-20211359
#
#                   topic_word  idf_value
# 0               localization   4.044522
# 1          data localization   4.044522
# 2             ai engineering   4.044522
# 3               ai lifecycle   2.791759
# 4    terminology data fabric   4.044522
# ..                       ...        ...
# 405                      pak   2.945910
# 406                 pak data   2.945910
# 407           cloud pak data   2.945910
# 408                cloud pak   2.945910
# 409                    azure   2.945910
#
# [410 rows x 3 columns]

# %%
# Select the top terms for each PDF
top_terms_df = result_df.groupby('Filename').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df['idf_value'] = top_terms_df['idf_value'] + np.random.rand(top_terms_df.shape[0]) * 0.0001

# Create a base chart
base = alt.Chart(top_terms_df).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Filename:N',
    color=alt.Color('idf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='topic_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("idf_value", order="descending")],
    groupby=["Filename"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='idf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle').encode(
    text='topic_word:N',
    color=alt.condition(alt.datum.idf_value >= 2.0, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_lda = (heatmap + text).properties(width=2000)

# %%
chart_lda
# Out:
# alt.LayerChart(...)

# %%
result_data_publisher = []

# Iterate through each row in the original DataFrame
for _, row in df.iterrows():
    Publisher = row['Publisher']
    topic_words = row['topic_words']

    # Iterate through each tuple in the list of topic_words
    for word, idf_value in topic_words:
        result_data_publisher.append({'Publisher': Publisher, 'topic_word': word, 'idf_value': idf_value})

# Create the result DataFrame from the list
result_df_publisher = pd.DataFrame(result_data_publisher)


result_df_publisher
# Out:
#          Publisher               topic_word  idf_value
# 0             IEEE             localization   4.044522
# 1             IEEE        data localization   4.044522
# 2             IEEE           ai engineering   4.044522
# 3             IEEE             ai lifecycle   2.791759
# 4             IEEE  terminology data fabric   4.044522
# ..             ...                      ...        ...
# 405  miscellaneous                      pak   2.945910
# 406  miscellaneous                 pak data   2.945910
# 407  miscellaneous           cloud pak data   2.945910
# 408  miscellaneous                cloud pak   2.945910
# 409  miscellaneous                    azure   2.945910
#
# [410 rows x 3 columns]

# %%
# Select the top terms for each PDF
top_terms_df = result_df_publisher.groupby('Publisher').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df['idf_value'] = top_terms_df['idf_value'] + np.random.rand(top_terms_df.shape[0]) * 0.0001

# Create a base chart
base = alt.Chart(top_terms_df).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Publisher:N',
    color=alt.Color('idf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='topic_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("idf_value", order="descending")],
    groupby=["Publisher"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='idf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle').encode(
    text='topic_word:N',
    color=alt.condition(alt.datum.idf_value >= 3.0, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_lda_publisher = (heatmap + text).properties(width=1500)
chart_lda_publisher
# Out:
# alt.LayerChart(...)

# %% [markdown]
# USING ONLY TFIDF

# %%
def find_top_words_for_each_document(df, num_top_words=10):

    # Create a TF-IDF vectorizer
    tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(2, 4), token_pattern=r'\b\w+\b')

    # Fit and transform the PDF content
    tfidf_matrix = tfidf_vectorizer.fit_transform(df['Content'])

    # Get feature names (words) from the TF-IDF vectorizer
    feature_names = tfidf_vectorizer.get_feature_names_out()

    # Create a DataFrame with TF-IDF values
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

    # Now, for each document, find the top words based on TF-IDF scores
    top_words_for_each_document = []
    for i, row in enumerate(tfidf_df.iterrows()):
        _, document_tfidf_scores = row
        top_words_index = document_tfidf_scores.argsort()[-num_top_words:][::-1]
        top_words = [(feature_names[index], document_tfidf_scores[index]) for index in top_words_index]
        top_words_for_each_document.append(top_words)

    # Create a new DataFrame with 'pdf_content' and 'top_words'
    result_df = pd.DataFrame({'Filename': df['Filename'], 'Content': df['Content'], 'top_words': top_words_for_each_document})

    return result_df

# %%
# Call the function
result_df_2 = find_top_words_for_each_document(df)

# Display the result DataFrame
result_df_2['Publisher'] = df['Publisher']
result_df_2
# Out:
#                                              Filename  \
# 0   Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 1   Decentralized_Data_Governance_as_Part_of_a_Dat...
# 2   Enterprise_Data_Strategy_A_Decentralized_Data_...
# 3   Finding_Your_Way_Through_the_Jungle_of_Big_Dat...
# 4                                 978-1-4842-9253-2_1
# 5                                978-1-4842-9253-2_10
# 6                                978-1-4842-9253-2_11
# 7                                978-1-4842-9253-2_12
# 8                                978-1-4842-9253-2_13
# 9                                978-1-4842-9253-2_14
# 10                               978-1-4842-9253-2_15
# 11                               978-1-4842-9253-2_16
# 12                               978-1-4842-9253-2_17
# 13                                978-1-4842-9253-2_2
# 14                                978-1-4842-9253-2_3
# 15                                978-1-4842-9253-2_4
# 16                                978-1-4842-9253-2_5
# 17                                978-1-4842-9253-2_6
# 18                                978-1-4842-9253-2_7
# 19                                978-1-4842-9253-2_8
# 20                                978-1-4842-9253-2_9
# 21                                978-3-031-12423-5_7
# 22                                  978-3-031-36118-0
# 23                                978-3-031-39847-6_1
# 24                               978-3-031-45021-1_23
# 25               AComparativeStudyofDataArchitectures
# 26  CowMesh_a_data-mesh_architecture_to_unify_dair...
# 27                             data-mesh-icws23-paper
# 28      Data_Mesh_a_Systematic_Gray_Literature_Review
# 29  Data_Mesh_Motivational_Factors_Challenges_and_...
# 30                            IJARCCE.2023.124121v2.0
# 31             majorchallengesinimplementingadatamesh
# 32  Navigating_the_Data_Architecture_Landscape_A_C...
# 33                              SKILL_2022_paper_8188
# 34                              SKILL_2022_paper_8188
# 35                                               0670
# 36                      1-s2.0-S1877050921022365-main
# 37                                         2302.01713
# 38                                               A3-2
# 39                       Diplomityo_Vinnikainen_Oskar
# 40                            urn_nbn_fi_uef-20211359
#
#                                               Content  \
# 0   chieve effective aggregation data localization...
# 1   pproaches arif wider sumedha verma atif akhtar...
# 2   decentralized data vijay kumar butte sujata bu...
# 3   rchitectures torsten priebe sebastian neumaier...
# 4   look back data architecture developed response...
# 5   provide high overview data fabric data evoluti...
# 6   saw data fabric architecture evolution previou...
# 7   look intersection two initiative digital trans...
# 8   metadata digital era enterprise know aspect da...
# 9   applying ai metadata intelligent cataloging da...
# 10  data constantly generated live data incredible...
# 11  goal data fabric provide flexible seamless aut...
# 12  must become obvious book unified data fabric a...
# 13  term data fabric data often viewed different c...
# 14  organization realized importance implementing ...
# 15  defining data fabric underlying data architect...
# 16  introduces key capability concept knowledge ca...
# 17  ai ml dl broadly speaking ai simulate human pe...
# 18  today data rich enterprise frequently confront...
# 19  data describe core entity referred master data...
# 20  ai lifecycle ai software engineering fundament...
# 21  dealing data privacy perspective important ind...
# 22  day amount collected stored processed analyzed...
# 23  data integration area active already six decad...
# 24  advent convergence operating technology ot inf...
# 25  digital age quantity data produced globally gr...
# 26  dairy industry experiencing strong global grow...
# 27  data socio technical decentralized analytics d...
# 28  world living golden age data idc data corporat...
# 29  volume data continues grow organization strivi...
# 30  technology advance data volume velocity increa...
# 31  major challenge implementing data cultural shi...
# 32  dynamic world data machine learning foundation...
# 33  world importance data continuously grows choos...
# 34  vailable author program chair procs author pro...
# 35  definition smart city coexist together single ...
# 36  inherent growing varied form software applicat...
# 37  volume data continues grow organization strivi...
# 38  world importance data continuously grows choos...
# 39  today live world important asset data accordin...
# 40  digital technology present almost every consum...
#
#                                             top_words      Publisher
# 0   [(data localization, 0.6461519865416517), (dat...           IEEE
# 1   [(data product, 0.3474289493730131), (output p...           IEEE
# 2   [(data product, 0.14960855571902104), (landing...           IEEE
# 3   [(logical data warehouse, 0.19271604639305134)...           IEEE
# 4   [(data architecture, 0.1593842444893316), (evo...       Springer
# 5   [(data fabric, 0.2457513522492156), (fabric da...       Springer
# 6   [(application architecture, 0.1647607467120480...       Springer
# 7   [(hybrid cloud, 0.38900951209618134), (data hy...       Springer
# 8   [(intelligent cataloging, 0.19566048410964015)...       Springer
# 9   [(fabric data aspect, 0.17310408189191503), (a...       Springer
# 10  [(data ai, 0.25481131697667925), (data data fa...       Springer
# 11  [(vendor offering, 0.16087285153256406), (samp...       Springer
# 12  [(semantic knowledge graph, 0.1481634486699342...       Springer
# 13  [(data fabric, 0.3164917983903526), (data prod...       Springer
# 14  [(data fabric data scenario, 0.189494872386893...       Springer
# 15  [(key driver, 0.12410315406874123), (data arch...       Springer
# 16  [(active metadata, 0.1520790270514245), (data ...       Springer
# 17  [(relevant ml dl, 0.18204827817168742), (ml dl...       Springer
# 18  [(ai ml, 0.18541487079819804), (ai ml data fab...       Springer
# 19  [(master data, 0.13889531884315615), (order ta...       Springer
# 20  [(ai engineering, 0.20217506451824366), (ai li...       Springer
# 21  [(quasi identi, 0.2194462711447197), (erential...       Springer
# 22  [(data platform, 0.09305748109013162), (data q...       Springer
# 23  [(data integration, 0.11815198176744691), (int...       Springer
# 24  [(analytical data, 0.09448855418117894), (data...       Springer
# 25  [(azure data, 0.22058267998125144), (azure dat...   ResearchGate
# 26  [(dairy farm, 0.14582289532490403), (data prod...   ResearchGate
# 27  [(data product, 0.3527346044513581), (output p...   ResearchGate
# 28  [(data product, 0.3675563813948644), (composit...   ResearchGate
# 29  [(data product, 0.191272385530722), (motivatio...   ResearchGate
# 30  [(data design, 0.08841783495484534), (analytic...   ResearchGate
# 31  [(data requires, 0.09281357546831726), (meet n...   ResearchGate
# 32  [(logical dwh, 0.12490106000823285), (data lak...   ResearchGate
# 33  [(year min, 0.10511065441731983), (data engine...   ResearchGate
# 34  [(smart monitoring, 0.47624539126450754), (mon...       Elsevier
# 35  [(smart city, 0.3974943847064804), (smart city...  miscellaneous
# 36  [(big data, 0.137162909605415), (data warehous...  miscellaneous
# 37  [(data product, 0.1622940389262621), (motivati...  miscellaneous
# 38  [(data architecture, 0.09226307982485911), (da...  miscellaneous
# 39  [(data product, 0.20685061964393295), (related...  miscellaneous
# 40  [(driven design, 0.08942184702796778), (softwa...  miscellaneous

# %%
result_data_3 = []

# Iterate through each row in the original DataFrame
for _, row in result_df_2.iterrows():
    Filename = row['Filename']
    top_words = row['top_words']

    # Iterate through each tuple in the list of top_words
    for word, tfidf in top_words:
        result_data_3.append({'Filename': Filename, 'topic_word': word, 'tfidf_value': tfidf})

# Create the result DataFrame from the list
result_df_3 = pd.DataFrame(result_data_3)

result_df_3
# Out:
#                                               Filename  \
# 0    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 1    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 2    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 3    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 4    Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# ..                                                 ...
# 405                            urn_nbn_fi_uef-20211359
# 406                            urn_nbn_fi_uef-20211359
# 407                            urn_nbn_fi_uef-20211359
# 408                            urn_nbn_fi_uef-20211359
# 409                            urn_nbn_fi_uef-20211359
#
#                  topic_word  tfidf_value
# 0         data localization     0.646152
# 1          data aggregation     0.079440
# 2         potential benefit     0.066134
# 3         localization data     0.064777
# 4    data localization data     0.062186
# ..                      ...          ...
# 405       data architecture     0.050306
# 406     ubiquitous language     0.049491
# 407          data framework     0.048799
# 408     conformed dimension     0.047457
# 409         theme interview     0.045546
#
# [410 rows x 3 columns]

# %%
# Select the top terms for each PDF
top_terms_df = result_df_3.groupby('Filename').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df['tfidf_value'] = top_terms_df['tfidf_value'] + np.random.rand(top_terms_df.shape[0]) * 0.0001

# Create a base chart
base = alt.Chart(top_terms_df).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Filename:N',
    color=alt.Color('tfidf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='topic_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("tfidf_value", order="descending")],
    groupby=["Filename"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='tfidf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle').encode(
    text='topic_word:N',
    color=alt.condition(alt.datum.tfidf_value >= 0.2, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_tfidf = (heatmap + text).properties(width=2000)

# %%
chart_tfidf
# Out:
# alt.LayerChart(...)

# %%
result_data_publisher_2 = []

# Iterate through each row in the original DataFrame
for _, row in result_df_2.iterrows():
    Publisher = row['Publisher']
    topic_words = row['top_words']

    # Iterate through each tuple in the list of topic_words
    for word, idf_value in topic_words:
        result_data_publisher_2.append({'Publisher': Publisher, 'top_word': word, 'idf_value': idf_value})

# Create the result DataFrame from the list
result_df_publisher_2 = pd.DataFrame(result_data_publisher_2)


result_df_publisher_2
# Out:
#          Publisher                top_word  idf_value
# 0             IEEE       data localization   0.646152
# 1             IEEE        data aggregation   0.079440
# 2             IEEE       potential benefit   0.066134
# 3             IEEE       localization data   0.064777
# 4             IEEE  data localization data   0.062186
# ..             ...                     ...        ...
# 405  miscellaneous       data architecture   0.050306
# 406  miscellaneous     ubiquitous language   0.049491
# 407  miscellaneous          data framework   0.048799
# 408  miscellaneous     conformed dimension   0.047457
# 409  miscellaneous         theme interview   0.045546
#
# [410 rows x 3 columns]

# %%
# Select the top terms for each PDF
top_terms_df_2 = result_df_publisher_2.groupby('Publisher').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df_2['idf_value'] = top_terms_df_2['idf_value'] + np.random.rand(top_terms_df_2.shape[0]) * 0.0001

# Create a base chart
base = alt.Chart(top_terms_df_2).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Publisher:N',
    color=alt.Color('idf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='top_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("idf_value", order="descending")],
    groupby=["Publisher"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='idf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle').encode(
    text='top_word:N',
    color=alt.condition(alt.datum.idf_value >= 0.4, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_lda_publisher_2 = (heatmap + text).properties(width=1500)
chart_lda_publisher_2
# Out:
# alt.LayerChart(...)
