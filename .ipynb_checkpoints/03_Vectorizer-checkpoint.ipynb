# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
# from gensim import corpora, models
# from gensim.models.ldamodel import LdaModel
from nltk.tokenize import word_tokenize
import altair as alt
from altair_saver import save
import os
import re
from nltk.util import ngrams
from itertools import chain

import numpy as np
import warnings
warnings.simplefilter("ignore")

# %%
df = pd.read_csv('Data_mesh_publications_cleaned.csv')
df_sample = df. copy()
df
# Out:
#                                              Filename  \
# 0   Breaking Down Data Silos Data Mesh to Achieve ...
# 1   Decentralized Data Governance as Part of a Dat...
# 2   Enterprise Data Strategy A Decentralized Data ...
# 3   Finding Your Way Through the Jungle of Big Dat...
# 4   CoK A Survey of Privacy Challenges in Relation...
# 5   Converging Data Mesh and Microservice Principl...
# 6   Data Integration Revitalized From Data Warehou...
# 7   Data Mesh as Distributed Data Platform for Lar...
# 8        Data Fabric and Data Mesh Approaches with AI
# 9   Cow Mesh a data-mesh architecture to unify dai...
# 10      Data Mesh a Systematic Gray Literature Review
# 11  Data Mesh Motivational Factors Challenges and ...
# 12  From Data Mess to Data Mesh Solution for Futur...
# 13  Identifying Alternatives and Deciding Factors ...
# 14         Navigating the Data Architecture Landscape
# 15  A Distributed Data Mesh Paradigm for an Event-...
# 16  Data Mesh Concepts and Principles of a Paradig...
# 17  Data Mesh A Holistic Examination Of Its Princi...
# 18  Introducing Data Mesh paradigm for Smart City ...
# 19  Towards avoiding the data mess Industry insigh...
# 20  Utilization of Data Mesh Framework as a Part o...
#
#                                               Content      Publisher  Year  \
# 0   abstract data localization law becoming make h...           IEEE  2023
# 1   abstract data socio technical decentralized an...           IEEE  2023
# 2   abstract enterprise experience exponential gro...           IEEE  2022
# 3   abstract paper present systematic ofcommon ana...           IEEE  2021
# 4   growing volume data appear multiple dis tribut...       Springer  2022
# 5   company invested driven design sup port data d...       Springer  2023
# 6   year data integration architecture evolved fro...       Springer  2023
# 7   rapid increase data volume last decade promote...       Springer  2023
# 8   look back data architecture developed response...       Springer  2023
# 9   dairy economically signi cant industry caters ...   ResearchGate  2023
# 10  world living golden age data idc data corporat...   ResearchGate  2023
# 11  volume data continues grow organization strivi...   ResearchGate  2023
# 12  technology advance data volume velocity increa...   ResearchGate  2023
# 13  data introduced new type data architecture pro...   ResearchGate  2022
# 14  rapidly evolving eld data numerous terminology...   ResearchGate  2023
# 15  smart capable independent action set rule trig...       Elsevier  2023
# 16  inherent growing varied form software applicat...       Elsevier  2021
# 17  today live world important asset data accordin...  miscellaneous  2023
# 18  concept smart city imposes unique set requirem...  miscellaneous  2023
# 19  volume data continues grow organization strivi...  miscellaneous  2023
# 20  digital technology present almost every consum...  miscellaneous  2021
#
#    Publication_type
# 0        conference
# 1        conference
# 2        conference
# 3        conference
# 4        conference
# 5        conference
# 6        conference
# 7        conference
# 8              book
# 9           journal
# 10          journal
# 11         preprint
# 12          journal
# 13       conference
# 14         preprint
# 15       conference
# 16       conference
# 17    master thesis
# 18       conference
# 19         preprint
# 20    master thesis

# %% [markdown]
# # TFIDF

# %%
# Define a function to preprocess text data
def preprocess_text(text):
    # Remove non-alphanumeric characters and special characters
    text = re.sub(r'[^a-zA-Z0-9\s-]', '', text)
    return text

# Preprocess the PDF content before fitting it to the TF-IDF vectorizer
df['Content'] = df['Content'].apply(preprocess_text)

# %%
def find_top_words_for_each_document(df, num_top_words=5):

    # Create a TF-IDF vectorizer
    tfidf_vectorizer = TfidfVectorizer(stop_words='english', ngram_range=(2, 4), token_pattern=r'\b\w[\w-]+\b')

    # Fit and transform the PDF content
    tfidf_matrix = tfidf_vectorizer.fit_transform(df['Content'])

    # Get feature names (words) from the TF-IDF vectorizer
    feature_names = tfidf_vectorizer.get_feature_names_out()

    # Create a DataFrame with TF-IDF values
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

    # Now, for each document, find the top words based on TF-IDF scores
    top_words_for_each_document = []
    for i, row in enumerate(tfidf_df.iterrows()):
        _, document_tfidf_scores = row
        top_words_index = document_tfidf_scores.argsort()[-num_top_words:][::-1]
        top_words = [(feature_names[index], document_tfidf_scores[index]) for index in top_words_index]
        top_words_for_each_document.append(top_words)

    # Create a new DataFrame with 'pdf_content' and 'top_words'
    result_df = pd.DataFrame({'Filename': df['Filename'],'Year': df['Year'],'Publisher': df['Publisher'],'Publication_type': df['Publication_type'], 'Content': df['Content'], 'top_words': top_words_for_each_document})

    return result_df

# %%
# Call the function
result_df_tfidf = find_top_words_for_each_document(df)
#result_df_tfidf

# %% [markdown]
# # Results with filename

# %%
result_data_tfidf_filename = []

# Iterate through each row in the original DataFrame
for _, row in result_df_tfidf.iterrows():
    Filename = row['Filename']
    top_words = row['top_words']

    # Iterate through each tuple in the list of top_words
    for word, tfidf in top_words:
        result_data_tfidf_filename.append({'Filename': Filename, 'topic_word': word, 'tfidf_value': tfidf})

# Create the result DataFrame from the list
result_df_tfidf_filename = pd.DataFrame(result_data_tfidf_filename)

# result_df_tfidf_filename

# %%
import pandas as pd

# Assuming result_df_3 is your DataFrame
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.max_rows', None) 
# pd.set_option('display.max_colwidth', None)# Show all rows

# Display the entire DataFrame
result_df_tfidf_filename
# Out:
#                                                                                          Filename  \
# 0        Breaking Down Data Silos Data Mesh to Achieve Effective Aggregation in Data Localization
# 1        Breaking Down Data Silos Data Mesh to Achieve Effective Aggregation in Data Localization
# 2        Breaking Down Data Silos Data Mesh to Achieve Effective Aggregation in Data Localization
# 3        Breaking Down Data Silos Data Mesh to Achieve Effective Aggregation in Data Localization
# 4        Breaking Down Data Silos Data Mesh to Achieve Effective Aggregation in Data Localization
# 5           Decentralized Data Governance as Part of a Data Mesh Platform Concepts and Approaches
# 6           Decentralized Data Governance as Part of a Data Mesh Platform Concepts and Approaches
# 7           Decentralized Data Governance as Part of a Data Mesh Platform Concepts and Approaches
# 8           Decentralized Data Governance as Part of a Data Mesh Platform Concepts and Approaches
# 9           Decentralized Data Governance as Part of a Data Mesh Platform Concepts and Approaches
# 10                                    Enterprise Data Strategy A Decentralized Data Mesh Approach
# 11                                    Enterprise Data Strategy A Decentralized Data Mesh Approach
# 12                                    Enterprise Data Strategy A Decentralized Data Mesh Approach
# 13                                    Enterprise Data Strategy A Decentralized Data Mesh Approach
# 14                                    Enterprise Data Strategy A Decentralized Data Mesh Approach
# 15                                  Finding Your Way Through the Jungle of Big Data Architectures
# 16                                  Finding Your Way Through the Jungle of Big Data Architectures
# 17                                  Finding Your Way Through the Jungle of Big Data Architectures
# 18                                  Finding Your Way Through the Jungle of Big Data Architectures
# 19                                  Finding Your Way Through the Jungle of Big Data Architectures
# 20                                  CoK A Survey of Privacy Challenges in Relation to Data Meshes
# 21                                  CoK A Survey of Privacy Challenges in Relation to Data Meshes
# 22                                  CoK A Survey of Privacy Challenges in Relation to Data Meshes
# 23                                  CoK A Survey of Privacy Challenges in Relation to Data Meshes
# 24                                  CoK A Survey of Privacy Challenges in Relation to Data Meshes
# 25           Converging Data Mesh and Microservice Principles into a Unified Logical Architecture
# 26           Converging Data Mesh and Microservice Principles into a Unified Logical Architecture
# 27           Converging Data Mesh and Microservice Principles into a Unified Logical Architecture
# 28           Converging Data Mesh and Microservice Principles into a Unified Logical Architecture
# 29           Converging Data Mesh and Microservice Principles into a Unified Logical Architecture
# 30                Data Integration Revitalized From Data Warehouse Through Data Lake to Data Mesh
# 31                Data Integration Revitalized From Data Warehouse Through Data Lake to Data Mesh
# 32                Data Integration Revitalized From Data Warehouse Through Data Lake to Data Mesh
# 33                Data Integration Revitalized From Data Warehouse Through Data Lake to Data Mesh
# 34                Data Integration Revitalized From Data Warehouse Through Data Lake to Data Mesh
# 35                          Data Mesh as Distributed Data Platform for Large Enterprise Companies
# 36                          Data Mesh as Distributed Data Platform for Large Enterprise Companies
# 37                          Data Mesh as Distributed Data Platform for Large Enterprise Companies
# 38                          Data Mesh as Distributed Data Platform for Large Enterprise Companies
# 39                          Data Mesh as Distributed Data Platform for Large Enterprise Companies
# 40                                                   Data Fabric and Data Mesh Approaches with AI
# 41                                                   Data Fabric and Data Mesh Approaches with AI
# 42                                                   Data Fabric and Data Mesh Approaches with AI
# 43                                                   Data Fabric and Data Mesh Approaches with AI
# 44                                                   Data Fabric and Data Mesh Approaches with AI
# 45   Cow Mesh a data-mesh architecture to unify dairy industry data for prediction and monitoring
# 46   Cow Mesh a data-mesh architecture to unify dairy industry data for prediction and monitoring
# 47   Cow Mesh a data-mesh architecture to unify dairy industry data for prediction and monitoring
# 48   Cow Mesh a data-mesh architecture to unify dairy industry data for prediction and monitoring
# 49   Cow Mesh a data-mesh architecture to unify dairy industry data for prediction and monitoring
# 50                                                  Data Mesh a Systematic Gray Literature Review
# 51                                                  Data Mesh a Systematic Gray Literature Review
# 52                                                  Data Mesh a Systematic Gray Literature Review
# 53                                                  Data Mesh a Systematic Gray Literature Review
# 54                                                  Data Mesh a Systematic Gray Literature Review
# 55                                   Data Mesh Motivational Factors Challenges and Best Practices
# 56                                   Data Mesh Motivational Factors Challenges and Best Practices
# 57                                   Data Mesh Motivational Factors Challenges and Best Practices
# 58                                   Data Mesh Motivational Factors Challenges and Best Practices
# 59                                   Data Mesh Motivational Factors Challenges and Best Practices
# 60                       From Data Mess to Data Mesh Solution for Futuristic Self-Serve Platforms
# 61                       From Data Mess to Data Mesh Solution for Futuristic Self-Serve Platforms
# 62                       From Data Mess to Data Mesh Solution for Futuristic Self-Serve Platforms
# 63                       From Data Mess to Data Mesh Solution for Futuristic Self-Serve Platforms
# 64                       From Data Mess to Data Mesh Solution for Futuristic Self-Serve Platforms
# 65                     Identifying Alternatives and Deciding Factors for a Data Mesh Architecture
# 66                     Identifying Alternatives and Deciding Factors for a Data Mesh Architecture
# 67                     Identifying Alternatives and Deciding Factors for a Data Mesh Architecture
# 68                     Identifying Alternatives and Deciding Factors for a Data Mesh Architecture
# 69                     Identifying Alternatives and Deciding Factors for a Data Mesh Architecture
# 70                                                     Navigating the Data Architecture Landscape
# 71                                                     Navigating the Data Architecture Landscape
# 72                                                     Navigating the Data Architecture Landscape
# 73                                                     Navigating the Data Architecture Landscape
# 74                                                     Navigating the Data Architecture Landscape
# 75       A Distributed Data Mesh Paradigm for an Event-based Smart Communities Monitoring Product
# 76       A Distributed Data Mesh Paradigm for an Event-based Smart Communities Monitoring Product
# 77       A Distributed Data Mesh Paradigm for an Event-based Smart Communities Monitoring Product
# 78       A Distributed Data Mesh Paradigm for an Event-based Smart Communities Monitoring Product
# 79       A Distributed Data Mesh Paradigm for an Event-based Smart Communities Monitoring Product
# 80                    Data Mesh Concepts and Principles of a Paradigm Shift in Data Architectures
# 81                    Data Mesh Concepts and Principles of a Paradigm Shift in Data Architectures
# 82                    Data Mesh Concepts and Principles of a Paradigm Shift in Data Architectures
# 83                    Data Mesh Concepts and Principles of a Paradigm Shift in Data Architectures
# 84                    Data Mesh Concepts and Principles of a Paradigm Shift in Data Architectures
# 85                   Data Mesh A Holistic Examination Of Its Principles, Practices, And Potential
# 86                   Data Mesh A Holistic Examination Of Its Principles, Practices, And Potential
# 87                   Data Mesh A Holistic Examination Of Its Principles, Practices, And Potential
# 88                   Data Mesh A Holistic Examination Of Its Principles, Practices, And Potential
# 89                   Data Mesh A Holistic Examination Of Its Principles, Practices, And Potential
# 90                                 Introducing Data Mesh paradigm for Smart City platforms design
# 91                                 Introducing Data Mesh paradigm for Smart City platforms design
# 92                                 Introducing Data Mesh paradigm for Smart City platforms design
# 93                                 Introducing Data Mesh paradigm for Smart City platforms design
# 94                                 Introducing Data Mesh paradigm for Smart City platforms design
# 95                Towards avoiding the data mess Industry insights from data mesh implementations
# 96                Towards avoiding the data mess Industry insights from data mesh implementations
# 97                Towards avoiding the data mess Industry insights from data mesh implementations
# 98                Towards avoiding the data mess Industry insights from data mesh implementations
# 99                Towards avoiding the data mess Industry insights from data mesh implementations
# 100                Utilization of Data Mesh Framework as a Part of Organization's Data Management
# 101                Utilization of Data Mesh Framework as a Part of Organization's Data Management
# 102                Utilization of Data Mesh Framework as a Part of Organization's Data Management
# 103                Utilization of Data Mesh Framework as a Part of Organization's Data Management
# 104                Utilization of Data Mesh Framework as a Part of Organization's Data Management
#
#                         topic_word  tfidf_value
# 0                data localization     0.642871
# 1                 data aggregation     0.077282
# 2                potential benefit     0.068927
# 3                localization data     0.065599
# 4           data localization data     0.062975
# 5                     data product     0.344843
# 6                      output port     0.189807
# 7             aligned data product     0.111778
# 8                     aligned data     0.101032
# 9                   source aligned     0.087637
# 10                    data product     0.085883
# 11                    landing zone     0.053984
# 12                 utc restriction     0.053068
# 13         limited utc restriction     0.053068
# 14                     limited utc     0.053068
# 15                     data fabric     0.129914
# 16                    logical data     0.128033
# 17          logical data warehouse     0.115791
# 18           architecture paradigm     0.092633
# 19                  data warehouse     0.090853
# 20                    quasi identi     0.230617
# 21                erential privacy     0.154718
# 22                       identi er     0.144482
# 23                 quasi identi er     0.139538
# 24              data anonymisation     0.117936
# 25                    data product     0.094897
# 26             smart manufacturing     0.066495
# 27                 analytical data     0.060280
# 28                 conversion data     0.054302
# 29                element required     0.044733
# 30                data integration     0.120218
# 31        integration architecture     0.090515
# 32                      smart city     0.074744
# 33   data integration architecture     0.072751
# 34                      modal data     0.067675
# 35                   data platform     0.071550
# 36                 siloed platform     0.063232
# 37          data quality assurance     0.059771
# 38                distributed data     0.059757
# 39                    layered data     0.059167
# 40                     data fabric     0.355611
# 41               knowledge catalog     0.224665
# 42                     fabric data     0.216979
# 43                data fabric data     0.214753
# 44                         data ai     0.182884
# 45                      dairy farm     0.152346
# 46                    data product     0.116659
# 47                       farm data     0.097064
# 48                   semantic data     0.090576
# 49          arti cial intelligence     0.080953
# 50                    data product     0.348605
# 51                  composite data     0.101015
# 52          composite data product     0.101015
# 53                 systematic gray     0.090705
# 54                      self serve     0.077521
# 55                    data product     0.182976
# 56             motivational factor     0.124120
# 57              challenge practice     0.119155
# 58                     data fabric     0.069205
# 59                factor challenge     0.067852
# 60                     data design     0.088779
# 61                    self service     0.075440
# 62                 analytical data     0.074214
# 63                    data product     0.070176
# 64                      data plane     0.067301
# 65                        year min     0.108861
# 66                data engineering     0.100112
# 67               data architecture     0.073692
# 68                alternative data     0.064713
# 69                     data fabric     0.059893
# 70                       le object     0.105072
# 71                      data vault     0.092599
# 72               data architecture     0.087094
# 73                       data lake     0.071973
# 74               le object storage     0.071299
# 75                smart monitoring     0.469289
# 76                    data product     0.147050
# 77                 monitoring data     0.125834
# 78           smart monitoring data     0.114045
# 79        smart monitoring product     0.081274
# 80                  data warehouse     0.121209
# 81                        big data     0.111939
# 82                    data product     0.100433
# 83                       data lake     0.090204
# 84               possible conclude     0.060582
# 85                    data product     0.223378
# 86                 related project     0.087127
# 87            data related project     0.087127
# 88                   key principle     0.074722
# 89               data architecture     0.071997
# 90                      smart city     0.388153
# 91                 smart city data     0.114920
# 92                       city data     0.095302
# 93                number different     0.081271
# 94                   user scenario     0.077837
# 95                    data product     0.132681
# 96              challenge practice     0.070732
# 97             motivational factor     0.069469
# 98                     data fabric     0.064469
# 99                 socio technical     0.052662
# 100                  driven design     0.086392
# 101           software development     0.072312
# 102                   data product     0.068521
# 103               data engineering     0.063784
# 104               question battery     0.054841

# %%
# Select the top terms for each PDF
top_terms_df_tfidf = result_df_tfidf_filename.groupby('Filename').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df_tfidf['tfidf_value'] = top_terms_df_tfidf['tfidf_value'] + np.random.rand(top_terms_df_tfidf.shape[0]) * 0.0001

# Create a base chart
base = alt.Chart(top_terms_df_tfidf).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Filename:N',
    color=alt.Color('tfidf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='topic_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("tfidf_value", order="descending")],
    groupby=["Filename"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='tfidf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle',fontWeight='bold').encode(
    text='topic_word:N',
    color=alt.condition(alt.datum.tfidf_value >= 0.4, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_tfidf = (heatmap + text).properties(width=1000)

# %%
# save(chart_tfidf, 'tfidf_heatmap.html')
chart_tfidf
# Out:
# alt.LayerChart(...)

# %% [markdown]
# # Result with publisher

# %%
result_data_tfidf_publisher = []

# Iterate through each row in the original DataFrame
for _, row in result_df_tfidf.iterrows():
    Publisher = row['Publisher']
    topic_words = row['top_words']

    # Iterate through each tuple in the list of topic_words
    for word, tfidf in topic_words:
        result_data_tfidf_publisher.append({'Publisher': Publisher, 'top_word': word, 'tf_idf_value': tfidf})

# Create the result DataFrame from the list
result_df_tfidf_publisher = pd.DataFrame(result_data_tfidf_publisher)


result_df_tfidf_publisher
# Out:
#          Publisher                       top_word  tf_idf_value
# 0             IEEE              data localization      0.642871
# 1             IEEE               data aggregation      0.077282
# 2             IEEE              potential benefit      0.068927
# 3             IEEE              localization data      0.065599
# 4             IEEE         data localization data      0.062975
# 5             IEEE                   data product      0.344843
# 6             IEEE                    output port      0.189807
# 7             IEEE           aligned data product      0.111778
# 8             IEEE                   aligned data      0.101032
# 9             IEEE                 source aligned      0.087637
# 10            IEEE                   data product      0.085883
# 11            IEEE                   landing zone      0.053984
# 12            IEEE                utc restriction      0.053068
# 13            IEEE        limited utc restriction      0.053068
# 14            IEEE                    limited utc      0.053068
# 15            IEEE                    data fabric      0.129914
# 16            IEEE                   logical data      0.128033
# 17            IEEE         logical data warehouse      0.115791
# 18            IEEE          architecture paradigm      0.092633
# 19            IEEE                 data warehouse      0.090853
# 20        Springer                   quasi identi      0.230617
# 21        Springer               erential privacy      0.154718
# 22        Springer                      identi er      0.144482
# 23        Springer                quasi identi er      0.139538
# 24        Springer             data anonymisation      0.117936
# 25        Springer                   data product      0.094897
# 26        Springer            smart manufacturing      0.066495
# 27        Springer                analytical data      0.060280
# 28        Springer                conversion data      0.054302
# 29        Springer               element required      0.044733
# 30        Springer               data integration      0.120218
# 31        Springer       integration architecture      0.090515
# 32        Springer                     smart city      0.074744
# 33        Springer  data integration architecture      0.072751
# 34        Springer                     modal data      0.067675
# 35        Springer                  data platform      0.071550
# 36        Springer                siloed platform      0.063232
# 37        Springer         data quality assurance      0.059771
# 38        Springer               distributed data      0.059757
# 39        Springer                   layered data      0.059167
# 40        Springer                    data fabric      0.355611
# 41        Springer              knowledge catalog      0.224665
# 42        Springer                    fabric data      0.216979
# 43        Springer               data fabric data      0.214753
# 44        Springer                        data ai      0.182884
# 45    ResearchGate                     dairy farm      0.152346
# 46    ResearchGate                   data product      0.116659
# 47    ResearchGate                      farm data      0.097064
# 48    ResearchGate                  semantic data      0.090576
# 49    ResearchGate         arti cial intelligence      0.080953
# 50    ResearchGate                   data product      0.348605
# 51    ResearchGate                 composite data      0.101015
# 52    ResearchGate         composite data product      0.101015
# 53    ResearchGate                systematic gray      0.090705
# 54    ResearchGate                     self serve      0.077521
# 55    ResearchGate                   data product      0.182976
# 56    ResearchGate            motivational factor      0.124120
# 57    ResearchGate             challenge practice      0.119155
# 58    ResearchGate                    data fabric      0.069205
# 59    ResearchGate               factor challenge      0.067852
# 60    ResearchGate                    data design      0.088779
# 61    ResearchGate                   self service      0.075440
# 62    ResearchGate                analytical data      0.074214
# 63    ResearchGate                   data product      0.070176
# 64    ResearchGate                     data plane      0.067301
# 65    ResearchGate                       year min      0.108861
# 66    ResearchGate               data engineering      0.100112
# 67    ResearchGate              data architecture      0.073692
# 68    ResearchGate               alternative data      0.064713
# 69    ResearchGate                    data fabric      0.059893
# 70    ResearchGate                      le object      0.105072
# 71    ResearchGate                     data vault      0.092599
# 72    ResearchGate              data architecture      0.087094
# 73    ResearchGate                      data lake      0.071973
# 74    ResearchGate              le object storage      0.071299
# 75        Elsevier               smart monitoring      0.469289
# 76        Elsevier                   data product      0.147050
# 77        Elsevier                monitoring data      0.125834
# 78        Elsevier          smart monitoring data      0.114045
# 79        Elsevier       smart monitoring product      0.081274
# 80        Elsevier                 data warehouse      0.121209
# 81        Elsevier                       big data      0.111939
# 82        Elsevier                   data product      0.100433
# 83        Elsevier                      data lake      0.090204
# 84        Elsevier              possible conclude      0.060582
# 85   miscellaneous                   data product      0.223378
# 86   miscellaneous                related project      0.087127
# 87   miscellaneous           data related project      0.087127
# 88   miscellaneous                  key principle      0.074722
# 89   miscellaneous              data architecture      0.071997
# 90   miscellaneous                     smart city      0.388153
# 91   miscellaneous                smart city data      0.114920
# 92   miscellaneous                      city data      0.095302
# 93   miscellaneous               number different      0.081271
# 94   miscellaneous                  user scenario      0.077837
# 95   miscellaneous                   data product      0.132681
# 96   miscellaneous             challenge practice      0.070732
# 97   miscellaneous            motivational factor      0.069469
# 98   miscellaneous                    data fabric      0.064469
# 99   miscellaneous                socio technical      0.052662
# 100  miscellaneous                  driven design      0.086392
# 101  miscellaneous           software development      0.072312
# 102  miscellaneous                   data product      0.068521
# 103  miscellaneous               data engineering      0.063784
# 104  miscellaneous               question battery      0.054841

# %%
result_df_tfidf_publisher.describe()
# Out:
#        tf_idf_value
# count    105.000000
# mean       0.115637
# std        0.090302
# min        0.044733
# 25%        0.069205
# 50%        0.087637
# 75%        0.119155
# max        0.642871

# %%
# Select the top terms for each PDF
top_terms_df_publisher = result_df_tfidf_publisher.groupby('Publisher').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df_publisher['tf_idf_value'] = top_terms_df_publisher['tf_idf_value'] + np.random.rand(top_terms_df_publisher.shape[0]) * 0.0001

# Create a base chart
base = alt.Chart(top_terms_df_publisher).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Publisher:N',
    color=alt.Color('tf_idf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='top_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("tf_idf_value", order="descending")],
    groupby=["Publisher"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='tf_idf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle',fontWeight='bold').encode(
    text='top_word:N',
    color=alt.condition(alt.datum.tf_idf_value >= 0.4, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_publisher = (heatmap + text).properties(width=1300)
chart_publisher
# Out:
# alt.LayerChart(...)

# %%
# save(chart_tfidf_publisher_2, 'tfidf_heatmap_publisher.html')

# %% [markdown]
# # Results with Publisher

# %%
result_data_tfidf_publication_type = []

# Iterate through each row in the original DataFrame
for _, row in result_df_tfidf.iterrows():
    Publication_type = row['Publication_type']
    topic_words = row['top_words']

    # Iterate through each tuple in the list of topic_words
    for word, tfidf in topic_words:
        result_data_tfidf_publication_type.append({'Publication_type': Publication_type, 'top_word': word, 'tf_idf_value': tfidf})

# Create the result DataFrame from the list
result_df_tfidf_publication_type = pd.DataFrame(result_data_tfidf_publication_type)


result_df_tfidf_publication_type
# Out:
#     Publication_type                       top_word  tf_idf_value
# 0         conference              data localization      0.642871
# 1         conference               data aggregation      0.077282
# 2         conference              potential benefit      0.068927
# 3         conference              localization data      0.065599
# 4         conference         data localization data      0.062975
# 5         conference                   data product      0.344843
# 6         conference                    output port      0.189807
# 7         conference           aligned data product      0.111778
# 8         conference                   aligned data      0.101032
# 9         conference                 source aligned      0.087637
# 10        conference                   data product      0.085883
# 11        conference                   landing zone      0.053984
# 12        conference                utc restriction      0.053068
# 13        conference        limited utc restriction      0.053068
# 14        conference                    limited utc      0.053068
# 15        conference                    data fabric      0.129914
# 16        conference                   logical data      0.128033
# 17        conference         logical data warehouse      0.115791
# 18        conference          architecture paradigm      0.092633
# 19        conference                 data warehouse      0.090853
# 20        conference                   quasi identi      0.230617
# 21        conference               erential privacy      0.154718
# 22        conference                      identi er      0.144482
# 23        conference                quasi identi er      0.139538
# 24        conference             data anonymisation      0.117936
# 25        conference                   data product      0.094897
# 26        conference            smart manufacturing      0.066495
# 27        conference                analytical data      0.060280
# 28        conference                conversion data      0.054302
# 29        conference               element required      0.044733
# 30        conference               data integration      0.120218
# 31        conference       integration architecture      0.090515
# 32        conference                     smart city      0.074744
# 33        conference  data integration architecture      0.072751
# 34        conference                     modal data      0.067675
# 35        conference                  data platform      0.071550
# 36        conference                siloed platform      0.063232
# 37        conference         data quality assurance      0.059771
# 38        conference               distributed data      0.059757
# 39        conference                   layered data      0.059167
# 40              book                    data fabric      0.355611
# 41              book              knowledge catalog      0.224665
# 42              book                    fabric data      0.216979
# 43              book               data fabric data      0.214753
# 44              book                        data ai      0.182884
# 45           journal                     dairy farm      0.152346
# 46           journal                   data product      0.116659
# 47           journal                      farm data      0.097064
# 48           journal                  semantic data      0.090576
# 49           journal         arti cial intelligence      0.080953
# 50           journal                   data product      0.348605
# 51           journal                 composite data      0.101015
# 52           journal         composite data product      0.101015
# 53           journal                systematic gray      0.090705
# 54           journal                     self serve      0.077521
# 55          preprint                   data product      0.182976
# 56          preprint            motivational factor      0.124120
# 57          preprint             challenge practice      0.119155
# 58          preprint                    data fabric      0.069205
# 59          preprint               factor challenge      0.067852
# 60           journal                    data design      0.088779
# 61           journal                   self service      0.075440
# 62           journal                analytical data      0.074214
# 63           journal                   data product      0.070176
# 64           journal                     data plane      0.067301
# 65        conference                       year min      0.108861
# 66        conference               data engineering      0.100112
# 67        conference              data architecture      0.073692
# 68        conference               alternative data      0.064713
# 69        conference                    data fabric      0.059893
# 70          preprint                      le object      0.105072
# 71          preprint                     data vault      0.092599
# 72          preprint              data architecture      0.087094
# 73          preprint                      data lake      0.071973
# 74          preprint              le object storage      0.071299
# 75        conference               smart monitoring      0.469289
# 76        conference                   data product      0.147050
# 77        conference                monitoring data      0.125834
# 78        conference          smart monitoring data      0.114045
# 79        conference       smart monitoring product      0.081274
# 80        conference                 data warehouse      0.121209
# 81        conference                       big data      0.111939
# 82        conference                   data product      0.100433
# 83        conference                      data lake      0.090204
# 84        conference              possible conclude      0.060582
# 85     master thesis                   data product      0.223378
# 86     master thesis                related project      0.087127
# 87     master thesis           data related project      0.087127
# 88     master thesis                  key principle      0.074722
# 89     master thesis              data architecture      0.071997
# 90        conference                     smart city      0.388153
# 91        conference                smart city data      0.114920
# 92        conference                      city data      0.095302
# 93        conference               number different      0.081271
# 94        conference                  user scenario      0.077837
# 95          preprint                   data product      0.132681
# 96          preprint             challenge practice      0.070732
# 97          preprint            motivational factor      0.069469
# 98          preprint                    data fabric      0.064469
# 99          preprint                socio technical      0.052662
# 100    master thesis                  driven design      0.086392
# 101    master thesis           software development      0.072312
# 102    master thesis                   data product      0.068521
# 103    master thesis               data engineering      0.063784
# 104    master thesis               question battery      0.054841

# %%
# Select the top terms for each PDF
top_terms_df_publication_type = result_df_tfidf_publication_type.groupby('Publication_type').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df_publication_type['tf_idf_value'] = top_terms_df_publication_type['tf_idf_value'] + np.random.rand(top_terms_df_publication_type.shape[0]) * 0.0001

# Create a base chart
base = alt.Chart(top_terms_df_publication_type).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Publication_type:N',
    color=alt.Color('tf_idf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='top_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("tf_idf_value", order="descending")],
    groupby=["Publication_type"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='tf_idf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle',fontWeight='bold').encode(
    text='top_word:N',
    color=alt.condition(alt.datum.tf_idf_value >= 0.4, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_publication_type = (heatmap + text).properties(width=1300)
chart_publication_type
# Out:
# alt.LayerChart(...)

# %%
result_data_tfidf_date = []

# Iterate through each row in the original DataFrame
for _, row in result_df_tfidf.iterrows():
    Year = row['Year']
    topic_words = row['top_words']

    # Iterate through each tuple in the list of topic_words
    for word, tfidf in topic_words:
        result_data_tfidf_date.append({'Year': Year, 'top_word': word, 'tf_idf_value': tfidf})

# Create the result DataFrame from the list
result_data_tfidf_date = pd.DataFrame(result_data_tfidf_date)


result_data_tfidf_date
# Out:
#      Year                       top_word  tf_idf_value
# 0    2023              data localization      0.642871
# 1    2023               data aggregation      0.077282
# 2    2023              potential benefit      0.068927
# 3    2023              localization data      0.065599
# 4    2023         data localization data      0.062975
# 5    2023                   data product      0.344843
# 6    2023                    output port      0.189807
# 7    2023           aligned data product      0.111778
# 8    2023                   aligned data      0.101032
# 9    2023                 source aligned      0.087637
# 10   2022                   data product      0.085883
# 11   2022                   landing zone      0.053984
# 12   2022                utc restriction      0.053068
# 13   2022        limited utc restriction      0.053068
# 14   2022                    limited utc      0.053068
# 15   2021                    data fabric      0.129914
# 16   2021                   logical data      0.128033
# 17   2021         logical data warehouse      0.115791
# 18   2021          architecture paradigm      0.092633
# 19   2021                 data warehouse      0.090853
# 20   2022                   quasi identi      0.230617
# 21   2022               erential privacy      0.154718
# 22   2022                      identi er      0.144482
# 23   2022                quasi identi er      0.139538
# 24   2022             data anonymisation      0.117936
# 25   2023                   data product      0.094897
# 26   2023            smart manufacturing      0.066495
# 27   2023                analytical data      0.060280
# 28   2023                conversion data      0.054302
# 29   2023               element required      0.044733
# 30   2023               data integration      0.120218
# 31   2023       integration architecture      0.090515
# 32   2023                     smart city      0.074744
# 33   2023  data integration architecture      0.072751
# 34   2023                     modal data      0.067675
# 35   2023                  data platform      0.071550
# 36   2023                siloed platform      0.063232
# 37   2023         data quality assurance      0.059771
# 38   2023               distributed data      0.059757
# 39   2023                   layered data      0.059167
# 40   2023                    data fabric      0.355611
# 41   2023              knowledge catalog      0.224665
# 42   2023                    fabric data      0.216979
# 43   2023               data fabric data      0.214753
# 44   2023                        data ai      0.182884
# 45   2023                     dairy farm      0.152346
# 46   2023                   data product      0.116659
# 47   2023                      farm data      0.097064
# 48   2023                  semantic data      0.090576
# 49   2023         arti cial intelligence      0.080953
# 50   2023                   data product      0.348605
# 51   2023                 composite data      0.101015
# 52   2023         composite data product      0.101015
# 53   2023                systematic gray      0.090705
# 54   2023                     self serve      0.077521
# 55   2023                   data product      0.182976
# 56   2023            motivational factor      0.124120
# 57   2023             challenge practice      0.119155
# 58   2023                    data fabric      0.069205
# 59   2023               factor challenge      0.067852
# 60   2023                    data design      0.088779
# 61   2023                   self service      0.075440
# 62   2023                analytical data      0.074214
# 63   2023                   data product      0.070176
# 64   2023                     data plane      0.067301
# 65   2022                       year min      0.108861
# 66   2022               data engineering      0.100112
# 67   2022              data architecture      0.073692
# 68   2022               alternative data      0.064713
# 69   2022                    data fabric      0.059893
# 70   2023                      le object      0.105072
# 71   2023                     data vault      0.092599
# 72   2023              data architecture      0.087094
# 73   2023                      data lake      0.071973
# 74   2023              le object storage      0.071299
# 75   2023               smart monitoring      0.469289
# 76   2023                   data product      0.147050
# 77   2023                monitoring data      0.125834
# 78   2023          smart monitoring data      0.114045
# 79   2023       smart monitoring product      0.081274
# 80   2021                 data warehouse      0.121209
# 81   2021                       big data      0.111939
# 82   2021                   data product      0.100433
# 83   2021                      data lake      0.090204
# 84   2021              possible conclude      0.060582
# 85   2023                   data product      0.223378
# 86   2023                related project      0.087127
# 87   2023           data related project      0.087127
# 88   2023                  key principle      0.074722
# 89   2023              data architecture      0.071997
# 90   2023                     smart city      0.388153
# 91   2023                smart city data      0.114920
# 92   2023                      city data      0.095302
# 93   2023               number different      0.081271
# 94   2023                  user scenario      0.077837
# 95   2023                   data product      0.132681
# 96   2023             challenge practice      0.070732
# 97   2023            motivational factor      0.069469
# 98   2023                    data fabric      0.064469
# 99   2023                socio technical      0.052662
# 100  2021                  driven design      0.086392
# 101  2021           software development      0.072312
# 102  2021                   data product      0.068521
# 103  2021               data engineering      0.063784
# 104  2021               question battery      0.054841

# %%
# Select the top terms for each PDF
top_terms_df_tfidf_dates = result_data_tfidf_date.groupby('Year').head(10)

# Add a small random value to 'idf_value' for better visualization
top_terms_df_tfidf_dates['tf_idf_value'] = top_terms_df_tfidf_dates['tf_idf_value'] + np.random.rand(top_terms_df_tfidf_dates.shape[0]) * 0.0001

# Create a base chart
# Create a base chart
base = alt.Chart(top_terms_df_tfidf_dates).encode(
    x=alt.X('rank:O', axis=None),  # Use rank for x-axis
    y='Year:N',
    color=alt.Color('tf_idf_value:Q', scale=alt.Scale(scheme='viridis')),
    text='top_word:N'  # Corrected column name to 'topic_word'
).transform_window(
    rank="rank()",
    sort=[alt.SortField("tf_idf_value", order="descending")],
    groupby=["Year"]
)

# Create a heatmap
heatmap = base.mark_rect().encode(
    color='tf_idf_value:Q',
)

# Create text labels with conditional color
text = base.mark_text(baseline='middle',fontWeight='bold').encode(
    text='top_word:N',
    color=alt.condition(alt.datum.tf_idf_value >= 0.4, alt.value('white'), alt.value('black'))
)

# Display the heatmap and text labels
chart_date_tfidf_type = (heatmap + text).properties(width=1300)
chart_date_tfidf_type
# Out:
# alt.LayerChart(...)
