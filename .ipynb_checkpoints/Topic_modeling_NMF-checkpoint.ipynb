# %% [markdown]
# To cluster the documents and annotate the clusters according to the main topic, we can use various natural language
# processing and machine learning techniques. Here is a general framework that can be used to accomplish this task:
#
# 1.Load the dataset into a pandas dataframe.
# 2.Clean the data by removing any null values or duplicates.
# 3.Preprocess the textual data (i.e., the abstracts) by removing stopwords, punctuation, and other noise. This can be done using various libraries like NLTK or spaCy.
# 4.Convert the preprocessed abstracts into a numerical representation using a technique like TF-IDF or Doc2Vec.
# 5. Find the relevant document
# 6.To find the main topic of each document, we will use a topic modeling algorithm such as Latent Dirichlet Allocation (LDA) or Non-negative Matrix Factorization (NMF)
# 6.For clustering and visualization, we will use a dimensionality reduction technique such as Principal Component Analysis (PCA) or t-SNE, and a visualization library such as bokeh.'''

# %%
'''Packages for preprocessing'''
import nltk 
from nltk.tokenize import word_tokenize,sent_tokenize

'''Pakages to load dataset'''
import pandas as pd

import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize
from sklearn.decomposition import NMF
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from bokeh.plotting import figure, show, output_file, ColumnDataSource
from bokeh.models import HoverTool


import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 


nltk.download('punkt')
nltk.download('stopwords')

from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mondal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mondal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
data = pd.read_csv("Data_mesh_cleaned.csv")
pdf_data = data.copy()

# %%
def NMF_modeling(df_data,components):
    
    df = df_data.copy()
    
 
    model = TfidfVectorizer(stop_words='english', max_df = 0.5, ngram_range=(2,3))
    word_vector = normalize(model.fit_transform(df['pdf_content']))
    nmf_model = NMF(n_components= components, init='nndsvd')
    nmf_model.fit(word_vector)
    df['topic'] = nmf_model.transform(word_vector).argmax(axis=1)
    
    topic_words = []
    n_words = 50
    
    feature_names = model.get_feature_names_out()
    for topic_idx, topic in enumerate(nmf_model.components_):
        top_words_idx = topic.argsort()[:-n_words - 1:-1]
        top_words = [feature_names[i] for i in top_words_idx]
        topic_words.append(', '.join(top_words))

    df['topic_words'] = [topic_words[i] for i in df['topic']]
    
    # Transform the topic_words column into a TF-IDF matrix
    tfidf_matrix = model.transform(df['topic_words'])
    dominant_words = []
    for i in range(len(df)):
        row = tfidf_matrix[i]
        dominant_word_idx = row.argmax()
        dominant_word = model.get_feature_names_out()[dominant_word_idx]
        dominant_words.append(dominant_word)

    # Add the dominant_word column to the DataFrame
    df['dominant_word'] = dominant_words
    
    return df

# %%
from sklearn.decomposition import LatentDirichletAllocation

def LDA_modeling(df_data, components):
    df = df_data.copy()

    # Create a TF-IDF vectorizer
    vectorizer = TfidfVectorizer(stop_words='english')
    word_vector = vectorizer.fit_transform(df['pdf_content'])

    # Fit an LDA model
    lda_model = LatentDirichletAllocation(n_components=components, random_state=42)
    lda_model.fit(word_vector)

    # Assign topics to documents
    df['topic'] = lda_model.transform(word_vector).argmax(axis=1)

    # Get top words for each topic
    topic_words = []
    n_words = 10
    feature_names = vectorizer.get_feature_names_out()
    
    for topic_idx, topic in enumerate(lda_model.components_):
        top_words_idx = topic.argsort()[:-n_words - 1:-1]
        top_words = [feature_names[i] for i in top_words_idx]
        topic_words.append(', '.join(top_words))

    df['topic_words'] = [topic_words[i] for i in df['topic']]

 
    tfidf_matrix = vectorizer.transform(df['topic_words'])
    
    
    dominant_words = []
    for i in range(len(df)):
        row = tfidf_matrix[i]
        dominant_word_idx = row.argmax()
        dominant_word = feature_names[dominant_word_idx]
        dominant_words.append(dominant_word)
    df['dominant_word'] = dominant_words

    return df

# %%
result = NMF_modeling(pdf_data, components = 20)

# %%
result
# Out:
#                                              pdf_name  \
# 0                                            0670.pdf
# 1                   1-s2.0-S1877050921022365-main.pdf
# 2                   1-s2.0-S1877050923006099-main.pdf
# 3                                      2302.01713.pdf
# 4                                      2304.01062.pdf
# 5                               978-1-4842-9253-2.pdf
# 6                             978-3-031-12423-5_7.pdf
# 7                               978-3-031-36118-0.pdf
# 8                             978-3-031-39847-6_1.pdf
# 9                            978-3-031-45021-1_23.pdf
# 10                                           A3-2.pdf
# 11           AComparativeStudyofDataArchitectures.pdf
# 12  Breaking_Down_Data_Silos_Data_Mesh_to_Achieve_...
# 13  CowMesh_a_data-mesh_architecture_to_unify_dair...
# 14                         data-mesh-icws23-paper.pdf
# 15  Data_Mesh_a_Systematic_Gray_Literature_Review.pdf
# 16  Data_Mesh_Motivational_Factors_Challenges_and_...
# 17  Decentralized_Data_Governance_as_Part_of_a_Dat...
# 18                   Diplomityo_Vinnikainen_Oskar.pdf
# 19  Enterprise_Data_Strategy_A_Decentralized_Data_...
# 20  Finding_Your_Way_Through_the_Jungle_of_Big_Dat...
# 21                        IJARCCE.2023.124121v2.0.pdf
# 22         majorchallengesinimplementingadatamesh.pdf
# 23  Navigating_the_Data_Architecture_Landscape_A_C...
# 24  Numerical Meth Engineering - 1998 - BEALL - A ...
# 25                          SKILL_2022_paper_8188.pdf
# 26                        urn_nbn_fi_uef-20211359.pdf
#
#                                           pdf_content  topic  \
# 0   introducing paradigm smart city platform desig...     13
# 1   available procedia computer science author pub...      5
# 2   available procedia computer science author pub...      5
# 3   best avoid mess jan bode ibm germany niklas kü...      2
# 4   systematic gray literature review abel goedege...      0
# 5   fabric approach ai guide ai based cataloging g...     15
# 6   cok survey privacy challenge relation mesh nik...     18
# 7   lecture note engineering communication technol...      6
# 8   integration revitalized warehouse lake robert ...      6
# 9   converging microservice principle uni ed logic...     10
# 10  identifying alternative deciding factor archit...      3
# 11  comparative study architecture azure lake lake...     14
# 12  breaking silo achieve effective aggregation lo...     19
# 13  typemethods published zero tnum four tnum octo...     12
# 14  see discussion st at pr ofiles public ation ht...      1
# 15  systematic gray literature review abel goedege...      0
# 16  factor challenge best jan bode ibm germany nik...      2
# 17  decentralized governance part platform concept...      1
# 18  holistic examination principle potential lappe...     17
# 19  enterprise strategy decentralized approach vij...      4
# 20  international conference big big finding way j...      4
# 21  see discussion st at pr ofiles public ation ht...     16
# 22  see discussion st at pr ofiles public ation ht...      9
# 23  review peer reviewed version navigating archit...      8
# 24  international numerical method engineering vol...     11
# 25  identifying alternative deciding architecture ...      3
# 26  utilization framework part organization manage...      7
#
#                                           topic_words           dominant_word
# 0   smart city, digital twin, user scenario, numbe...              smart city
# 1   smart monitoring, event based, event based sma...                   nc nd
# 2   smart monitoring, event based, event based sma...                   nc nd
# 3   http doi, http doi org, doi org, challenge bes...                 kühl et
# 4   gray literature, platform service, manuscript ...             abel indika
# 5   knowledge catalog, ai ml, chapter fabri, hybri...                cloud ai
# 6   quasi identi, quasi identi er, identi er, eren...      challenge relation
# 7   di process, http doi org, http doi, doi org, i...              ed iccseea
# 8   di process, http doi org, http doi, doi org, i...              ed iccseea
# 9   microservice principle, bounded context, morai...        element required
# 10  year min, company structure, company culture, ...           min anonymous
# 11  azure lake, high high, azure lake lakehouse, l...               high high
# 12  abstraction model, potential benefit, differen...             october utc
# 13  tnum tnum, tnum tnum tnum, zero tnum, tnum zer...               tnum tnum
# 14  output port, reference implementation, aligned...         aligned product
# 15  gray literature, platform service, manuscript ...             abel indika
# 16  http doi, http doi org, doi org, challenge bes...                 kühl et
# 17  output port, reference implementation, aligned...         aligned product
# 18  related project, challenge related, technology...          cloud adoption
# 19  logical warehouse, architecture paradigm, land...       analytics busines
# 20  logical warehouse, architecture paradigm, land...       analytics busines
# 21  april doi, engineering iso certified, ijarcce ...  international advanced
# 22  major challenge implementing, ed lin, wilfr ed...             ation major
# 23  preprints org, doi preprints, october doi, oct...                 bl self
# 24  onlinelibrary wiley, http onlinelibrary wiley,...           wiley library
# 25  year min, company structure, company culture, ...           min anonymous
# 26  case organization, theme interview, driven des...            common model

# %%
word_list = result['topic_words'].str.split(',').explode().tolist()

# %%
len(word_list)
# Out:
# 1350

# %%
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Use Counter to count word frequencies
word_count = Counter(word_list)

# %%
# Get the 10 most common words
most_common_words = word_count.most_common(50)

# Extract the words and their frequencies
words, frequencies = zip(*most_common_words)

# Create a bar plot
plt.figure(figsize=(10, 20))
plt.barh(words, frequencies)
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.title('Top 10 Most Frequent Words')
plt.gca().invert_yaxis()  # Invert the y-axis to have the most frequent word at the top
plt.show()
