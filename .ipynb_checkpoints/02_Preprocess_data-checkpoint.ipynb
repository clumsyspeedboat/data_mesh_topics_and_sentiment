# %%
'''THis block of code pre processes the data'''
from nltk.stem import WordNetLemmatizer
import re
import nltk
import pandas as pd
from nltk.corpus import stopwords
lemmatizer = WordNetLemmatizer()
from nltk.tokenize import word_tokenize,sent_tokenize

import csv
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = 'Data_mesh_publications.csv'

# Read the TSV file and convert it to a DataFrame
df = pd.read_csv(file_path, delimiter=',')
df
# Out:
#                                              Filename  \
# 0   Breaking Down Data Silos Data Mesh to Achieve ...
# 1   Decentralized Data Governance as Part of a Dat...
# 2   Enterprise Data Strategy A Decentralized Data ...
# 3   Finding Your Way Through the Jungle of Big Dat...
# 4   CoK A Survey of Privacy Challenges in Relation...
# 5   Converging Data Mesh and Microservice Principl...
# 6   Data Integration Revitalized From Data Warehou...
# 7   Data Mesh as Distributed Data Platform for Lar...
# 8        Data Fabric and Data Mesh Approaches with AI
# 9   Cow Mesh a data-mesh architecture to unify dai...
# 10      Data Mesh a Systematic Gray Literature Review
# 11  Data Mesh Motivational Factors Challenges and ...
# 12  From Data Mess to Data Mesh Solution for Futur...
# 13  Identifying Alternatives and Deciding Factors ...
# 14         Navigating the Data Architecture Landscape
# 15  A Distributed Data Mesh Paradigm for an Event-...
# 16  Data Mesh Concepts and Principles of a Paradig...
# 17  Data Mesh A Holistic Examination Of Its Princi...
# 18  Introducing Data Mesh paradigm for Smart City ...
# 19  Towards avoiding the data mess Industry insigh...
# 20  Utilization of Data Mesh Framework as a Part o...
#
#                                               Content      Publisher  Year  \
# 0                 Abstract— Data localization laws...           IEEE  2023
# 1   Abstract  —Data  mesh  is  a  socio-technical ...           IEEE  2023
# 2   Abstract— As the enterprises experience expone...           IEEE  2022
# 3   Abstract—This paper presents a systematic revi...           IEEE  2021
# 4   . The growing volumes of data that appear on m...       Springer  2022
# 5   . Companies have invested in Domain-Driven Des...       Springer  2023
# 6   . For years, data integration (DI) architectur...       Springer  2023
# 7   . Rapid increase in data volume during the las...       Springer  2023
# 8   When you look back in time, data architectures...       Springer  2023
# 9   Dairy is an economically signiﬁcant industry t...   ResearchGate  2023
# 10  The world is living in the golden age of data....   ResearchGate  2023
# 11  As the volume of data continues to grow, organ...   ResearchGate  2023
# 12  : As technology advances, data volume and velo...   ResearchGate  2023
# 13  : The data mesh was introduced in 2019 as a ne...   ResearchGate  2022
# 14  : In the rapidly evolving ﬁeld of data managem...   ResearchGate  2023
# 15    A smart system is a system capable of indepe...       Elsevier  2023
# 16    Inherent to the growing use of the most vari...       Elsevier  2021
# 17   Today we live in a world where one of the mos...  miscellaneous  2023
# 18      The concept of a smart city imposes a uniq...  miscellaneous  2023
# 19  As the volume of data continues to grow, organ...  miscellaneous  2023
# 20   Digital technology is present in almost every...  miscellaneous  2021
#
#    Publication_type
# 0        conference
# 1        conference
# 2        conference
# 3        conference
# 4        conference
# 5        conference
# 6        conference
# 7        conference
# 8              book
# 9           journal
# 10          journal
# 11         preprint
# 12          journal
# 13       conference
# 14         preprint
# 15       conference
# 16       conference
# 17    master thesis
# 18       conference
# 19         preprint
# 20    master thesis

# %%
# Load stop words from NLTK library
nltk.download('wordnet')
nltk.download("stopwords")
nltk_stop_words = set(stopwords.words('english'))
print("Number of stop words from NLTK:", len(nltk_stop_words))

# Load stop words from CSV file into a DataFrame with the appropriate encoding
csv_file_path = "Data_mesh_stop_words.csv"
words_df = pd.read_csv(csv_file_path, header=None, names=["stopword"], encoding="ISO-8859-1")
custom_stop_words = set(map(str.lower, words_df["stopword"]))

# Combine stop words from both sources
stop_words = nltk_stop_words.union(custom_stop_words)

# Add words from CSV file to stop_words set
with open(csv_file_path, mode='r') as file:
    reader = csv.reader(file)
    # Skip header
    next(reader, None)
    # Add words to stop_words set
    for row in reader:
        word = row[0].lower().strip()
       
        stop_words.add(word)
# Out:
# Number of stop words from NLTK: 179
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mondal\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\mondal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
words_to_check = ['http', 'com', 'author','license' ]

# Check if each word is in stop_words, and if not, add it
for word in words_to_check:
    if word not in stop_words:
        print(f"Adding '{word}' to stop_words")
        stop_words.add(word)

# Print the updated stop_words set
print("Updated stop words set:", stop_words, len(stop_words))
# Out:
# Updated stop words set: {'had', 'until', 'case', 'at', 'not', 'access', 'ain', 'conference', 'licensed', 't', 'myself', 'ourselves', 'ation', 'central', 'because', 'analysis', 'license', ' factor', 'won', 'araújo', 'coef', 'me', 'all', 'now', 'itself', 'your', 'where', 'see', 'international', 'them', 're', 'article', 'kayem', 'more', 'lin', 'or', 'any', 'many', 'dama', 'there', "couldn't", 'springer', 'o', 'scientific', 'she', 'dehghani', 'wiley', 'did', 'further', 'open', 'theirs', 'will', "needn't", 'xx', 'process', 'company', 'ag', 'same', 'the', 'down', 'isn', 'araãºjo', 'url', 'from', 'our', 'should', 'approach', 'year\xa0', 'after', 'him', 'available', 'and', 'library', 'hers', 'inês', 'detection', 'during', 'to', 'in', 'on', 'team', 'ingolstadt', 'preprint', 'with', 'portugal', 'factor', 'below', 'pp', 'doing', 'xxx', 'sciencedirect', 'using', "hasn't", 've', 'mesh', 'pozna?', 'only', 'was', 'org', 'have', 'committee', 'than', 'author', 'domain', 'paradigm', 'podlesny\xa0', 'which', 'again', 'based', 'mightn', 'chapter', 'mustn', "mightn't", 'were', 'machado', 'certified', 'hub', 'poznan', 'section', 'what', 'challenge\xa0', 'interview', 'university', 'challenge', 'year', 's', 'ibm', "didn't", 'best', 'of', 'araújo ', 'governance', 'yourself', "wasn't", 'having', 'do', "you'd", 'vldb', "don't", 'care', 'preprints\xa0', 'haven', 'shouldn', 'di', 'himself', 'they', 'factor\xa0', 'yours', 'i', 'by', 'layer', "won't", "wouldn't", 'when', 'yourselves', 'weren', 'vol', 'for', 'technische', 'out', 'hu', "you're", 'science', 'such', 'literature', 'creativecommons', 'apply', 'level', 'then', 'platform', 'computer', 'http', 'above', 'that', 'authorized', 'he', 'addressed\xa0', 'khalil', 'you', 'nc', 'cc', 'published', 'schultze', 'background', 'method', 'health', 'elsevier', 'so', 'interviewee', 'tjoa\xa0', 'direct', 'result', 'each', 'note', 'these', "doesn't", 'themselves', 'shan', 'once', 'mf', 'project', 'wilfr\xa0', 'about', 'my', 'predefined', 'being', 'over', 'internet', 'october', "that'll", 'event', 'expert', 'ma', 'wilfr', 'enterprise', 'why', 'need', 'term', 'few', 'centeris', 'before', 'one', 'couldn', 'rule', 'peer', 'social', 'hcist', 'tnum', 'ieee', 'organization', 'hadn', "aren't", 'didn', 'research', 'hasn', 'too', 'responsibility', 'wasn', 'com', 'context', 'don', 'doesn', 'st', "haven't", 'online', 'manuscript', 'coef\xa0', 'reviewed', "shouldn't", 'figure', 'both', 'business', 'some', 'system', 'been', 'dmbok', 'very', 'be', 'condition', 'procedia', 'if', 'used', 'xxxx', 'information', 'podlesny', 'needn', 'tjoa', 'this', 'can', 'd', "you'll", 'multi', 'its', 'discussion', 'use', 'preprints', 'while', 'college\xa0', 'numerical', 'but', 'm', 'whom', 'through', 'as', 'february', 'their', 'thesis', 'word', 'practice', 'fig', 'off', 'own', 'management', 'a', 'into', 'way', "hadn't", 'face', 'doi', 'worapol', 'college', 'nd', 'how', 'zero', 'her', 'is', 'xplore', 'y', 'rent', 'addressed', 'we', 'license ', 'just', 'trying', 'no', 'between', 'cited', 'most', 'has', 'here', 'public', 'wouldn', 'who', 'also', 'review', 'against', 'his', 'herself', 'lncs', 'motivaltionl', 'www', 'got', "you've", 'model', 'are', "mustn't", "shan't", "she's", "it's", 'does', 'those', "isn't", 'et', 'work', 'er', 'under', 'an', 'comparative', 'al', 'common', 'ed', 'up', 'onlinelibrary', "weren't", 'cient', 'll', 'am', "should've", 'other', 'nor', 'hochschule', 'ours', 'aren', 'tions', 'downloaded', 'it', 'time'} 367

# %%
def clean_text(text):
    
    # Remove HTML tags and non-English characters
    text = re.sub(r"<[^>]+>", "", str(text))
    text = re.sub(r"[^A-Za-zÀ-ž ]", " ", str(text))

    # Tokenize and convert to lowercase
    word_tokens = word_tokenize(text)
    words_tokens_lower = [word.lower() for word in word_tokens]

    # Remove single characters and numbers
    words_filtered = [word for word in words_tokens_lower if len(word) > 1 and not word.isnumeric()]

    # Remove stop words
    words_filtered = [word for word in words_filtered if word not in stop_words]

    # Lemmatize words
    words_lemmatized = [lemmatizer.lemmatize(word) for word in words_filtered]

    # Join the words back into a string
    text_clean = " ".join(words_lemmatized)
    return text_clean

# %%
pdf_data = df.dropna(axis = 0, how = 'any', inplace = False)
    
# pdf_data = df.copy()
# drop_nan(pdf_data)
pdf_data['Content'] = pdf_data['Content'].apply(clean_text)

# %%
pdf_data
# Out:
#                                              Filename  \
# 0   Breaking Down Data Silos Data Mesh to Achieve ...
# 1   Decentralized Data Governance as Part of a Dat...
# 2   Enterprise Data Strategy A Decentralized Data ...
# 3   Finding Your Way Through the Jungle of Big Dat...
# 4   CoK A Survey of Privacy Challenges in Relation...
# 5   Converging Data Mesh and Microservice Principl...
# 6   Data Integration Revitalized From Data Warehou...
# 7   Data Mesh as Distributed Data Platform for Lar...
# 8        Data Fabric and Data Mesh Approaches with AI
# 9   Cow Mesh a data-mesh architecture to unify dai...
# 10      Data Mesh a Systematic Gray Literature Review
# 11  Data Mesh Motivational Factors Challenges and ...
# 12  From Data Mess to Data Mesh Solution for Futur...
# 13  Identifying Alternatives and Deciding Factors ...
# 14         Navigating the Data Architecture Landscape
# 15  A Distributed Data Mesh Paradigm for an Event-...
# 16  Data Mesh Concepts and Principles of a Paradig...
# 17  Data Mesh A Holistic Examination Of Its Princi...
# 18  Introducing Data Mesh paradigm for Smart City ...
# 19  Towards avoiding the data mess Industry insigh...
# 20  Utilization of Data Mesh Framework as a Part o...
#
#                                               Content      Publisher  Year  \
# 0   abstract data localization law becoming make h...           IEEE  2023
# 1   abstract data socio technical decentralized an...           IEEE  2023
# 2   abstract enterprise experience exponential gro...           IEEE  2022
# 3   abstract paper present systematic ofcommon ana...           IEEE  2021
# 4   growing volume data appear multiple dis tribut...       Springer  2022
# 5   company invested driven design sup port data d...       Springer  2023
# 6   year data integration architecture evolved fro...       Springer  2023
# 7   rapid increase data volume last decade promote...       Springer  2023
# 8   look back data architecture developed response...       Springer  2023
# 9   dairy economically signi cant industry caters ...   ResearchGate  2023
# 10  world living golden age data idc data corporat...   ResearchGate  2023
# 11  volume data continues grow organization strivi...   ResearchGate  2023
# 12  technology advance data volume velocity increa...   ResearchGate  2023
# 13  data introduced new type data architecture pro...   ResearchGate  2022
# 14  rapidly evolving eld data numerous terminology...   ResearchGate  2023
# 15  smart capable independent action set rule trig...       Elsevier  2023
# 16  inherent growing varied form software applicat...       Elsevier  2021
# 17  today live world important asset data accordin...  miscellaneous  2023
# 18  concept smart city imposes unique set requirem...  miscellaneous  2023
# 19  volume data continues grow organization strivi...  miscellaneous  2023
# 20  digital technology present almost every consum...  miscellaneous  2021
#
#    Publication_type
# 0        conference
# 1        conference
# 2        conference
# 3        conference
# 4        conference
# 5        conference
# 6        conference
# 7        conference
# 8              book
# 9           journal
# 10          journal
# 11         preprint
# 12          journal
# 13       conference
# 14         preprint
# 15       conference
# 16       conference
# 17    master thesis
# 18       conference
# 19         preprint
# 20    master thesis

# %%
df_subset = pdf_data[['Filename','Publisher','Year','Publication_type']]
df_subset_sorted = df_subset.sort_values(by='Year', ascending=True)
df_subset_sorted
print(df_subset_sorted.to_latex(index=False))
# Out:
# \begin{tabular}{llrl}
# \toprule
# Filename & Publisher & Year & Publication_type \\
# \midrule
# Utilization of Data Mesh Framework as a Part of Organization's Data Management & miscellaneous & 2021 & master thesis \\
# Finding Your Way Through the Jungle of Big Data Architectures & IEEE & 2021 & conference \\
# Data Mesh Concepts and Principles of a Paradigm Shift in Data Architectures & Elsevier & 2021 & conference \\
# Enterprise Data Strategy A Decentralized Data Mesh Approach & IEEE & 2022 & conference \\
# CoK A Survey of Privacy Challenges in Relation to Data Meshes & Springer & 2022 & conference \\
# Identifying Alternatives and Deciding Factors for a Data Mesh Architecture & ResearchGate & 2022 & conference \\
# Introducing Data Mesh paradigm for Smart City platforms design & miscellaneous & 2023 & conference \\
# Data Mesh A Holistic Examination Of Its Principles, Practices, And Potential & miscellaneous & 2023 & master thesis \\
# A Distributed Data Mesh Paradigm for an Event-based Smart Communities Monitoring Product & Elsevier & 2023 & conference \\
# Navigating the Data Architecture Landscape & ResearchGate & 2023 & preprint \\
# From Data Mess to Data Mesh Solution for Futuristic Self-Serve Platforms & ResearchGate & 2023 & journal \\
# Breaking Down Data Silos Data Mesh to Achieve Effective Aggregation in Data Localization & IEEE & 2023 & conference \\
# Towards avoiding the data mess Industry insights from data mesh implementations & miscellaneous & 2023 & preprint \\
# Cow Mesh a data-mesh architecture to unify dairy industry data for prediction and monitoring & ResearchGate & 2023 & journal \\
# Data Fabric and Data Mesh Approaches with AI & Springer & 2023 & book \\
# Data Mesh as Distributed Data Platform for Large Enterprise Companies & Springer & 2023 & conference \\
# Data Integration Revitalized From Data Warehouse Through Data Lake to Data Mesh & Springer & 2023 & conference \\
# Converging Data Mesh and Microservice Principles into a Unified Logical Architecture & Springer & 2023 & conference \\
# Decentralized Data Governance as Part of a Data Mesh Platform Concepts and Approaches & IEEE & 2023 & conference \\
# Data Mesh Motivational Factors Challenges and Best Practices & ResearchGate & 2023 & preprint \\
# Data Mesh a Systematic Gray Literature Review & ResearchGate & 2023 & journal \\
# \bottomrule
# \end{tabular}

# %%
# Assuming 'pdf_content' column contains the cleaned text
text_combined = ' '.join(pdf_data['Content'])

# Tokenize the text
tokens = word_tokenize(text_combined)

# Count the frequency of each word
word_freq = nltk.FreqDist(tokens)

# Create a DataFrame from the frequency distribution
word_freq_df = pd.DataFrame(list(word_freq.items()), columns=['Word', 'Frequency'])

# Sort the DataFrame by frequency in descending order
word_freq_df = word_freq_df.sort_values(by='Frequency', ascending=False)
word_freq_df
# Out:
#                      Word  Frequency
# 1                    data     208816
# 143               product      29504
# 22           architecture      16582
# 35           organization       9793
# 293               service       8882
# ...                   ...        ...
# 7996  liatedorganizations          1
# 7995           theauthors          1
# 7994              noteall          1
# 7993          beconstrued          1
# 9804                 uidb          1
#
# [11129 rows x 2 columns]

# %%
word_freq_df = word_freq_df[word_freq_df['Word'] != 'data']

# %%
# Plot the top N words by frequency in a bar chart
plt.figure(figsize=(10, 3))

# Choose a Seaborn color palette (e.g., 'flare')
original_palette = sns.color_palette('crest', n_colors=50)

# Invert the color palette
# inverted_palette = sns.color_palette('crest', n_colors=50)[::-1]

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Manually add the title as text inside the plot
plt.text(0.7, 0.8, 'Top 20 words by individual frequency \n [excluding "data" (208,816 times)]', horizontalalignment='center', fontsize=16, transform=plt.gca().transAxes)

sns.barplot(x='Word', y='Frequency', data=word_freq_df.head(20), palette=original_palette, hue = 'Word')
# plt.title('Top 20 words by individual frequency \n [excluding "data"(208,816 times)]')
plt.ylabel('Frequency')
plt.xlabel('')
plt.xticks(rotation=45, ha='right')

# plt.savefig('word_occurrence.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# c:\Temp\ipykernel_8972\1497732553.py:16: UserWarning: The palette list has more values (50) than needed (20), which may not be intended.
#   sns.barplot(x='Word', y='Frequency', data=word_freq_df.head(20), palette=original_palette, hue = 'Word')

# %%
pdf_data
# Out:
#                                              Filename  \
# 0   Breaking Down Data Silos Data Mesh to Achieve ...
# 1   Decentralized Data Governance as Part of a Dat...
# 2   Enterprise Data Strategy A Decentralized Data ...
# 3   Finding Your Way Through the Jungle of Big Dat...
# 4   CoK A Survey of Privacy Challenges in Relation...
# 5   Converging Data Mesh and Microservice Principl...
# 6   Data Integration Revitalized From Data Warehou...
# 7   Data Mesh as Distributed Data Platform for Lar...
# 8        Data Fabric and Data Mesh Approaches with AI
# 9   Cow Mesh a data-mesh architecture to unify dai...
# 10      Data Mesh a Systematic Gray Literature Review
# 11  Data Mesh Motivational Factors Challenges and ...
# 12  From Data Mess to Data Mesh Solution for Futur...
# 13  Identifying Alternatives and Deciding Factors ...
# 14         Navigating the Data Architecture Landscape
# 15  A Distributed Data Mesh Paradigm for an Event-...
# 16  Data Mesh Concepts and Principles of a Paradig...
# 17  Data Mesh A Holistic Examination Of Its Princi...
# 18  Introducing Data Mesh paradigm for Smart City ...
# 19  Towards avoiding the data mess Industry insigh...
# 20  Utilization of Data Mesh Framework as a Part o...
#
#                                               Content      Publisher  Year  \
# 0   abstract data localization law becoming make h...           IEEE  2023
# 1   abstract data socio technical decentralized an...           IEEE  2023
# 2   abstract enterprise experience exponential gro...           IEEE  2022
# 3   abstract paper present systematic ofcommon ana...           IEEE  2021
# 4   growing volume data appear multiple dis tribut...       Springer  2022
# 5   company invested driven design sup port data d...       Springer  2023
# 6   year data integration architecture evolved fro...       Springer  2023
# 7   rapid increase data volume last decade promote...       Springer  2023
# 8   look back data architecture developed response...       Springer  2023
# 9   dairy economically signi cant industry caters ...   ResearchGate  2023
# 10  world living golden age data idc data corporat...   ResearchGate  2023
# 11  volume data continues grow organization strivi...   ResearchGate  2023
# 12  technology advance data volume velocity increa...   ResearchGate  2023
# 13  data introduced new type data architecture pro...   ResearchGate  2022
# 14  rapidly evolving eld data numerous terminology...   ResearchGate  2023
# 15  smart capable independent action set rule trig...       Elsevier  2023
# 16  inherent growing varied form software applicat...       Elsevier  2021
# 17  today live world important asset data accordin...  miscellaneous  2023
# 18  concept smart city imposes unique set requirem...  miscellaneous  2023
# 19  volume data continues grow organization strivi...  miscellaneous  2023
# 20  digital technology present almost every consum...  miscellaneous  2021
#
#    Publication_type
# 0        conference
# 1        conference
# 2        conference
# 3        conference
# 4        conference
# 5        conference
# 6        conference
# 7        conference
# 8              book
# 9           journal
# 10          journal
# 11         preprint
# 12          journal
# 13       conference
# 14         preprint
# 15       conference
# 16       conference
# 17    master thesis
# 18       conference
# 19         preprint
# 20    master thesis

# %%
csv_filename = 'Data_mesh_publications_cleaned.csv'

# Save the DataFrame to a CSV file
pdf_data.to_csv(csv_filename, index=False)

# %%
import numpy as np
import networkx as nx
from sklearn.feature_extraction.text import CountVectorizer

import matplotlib.colors as mcolors
import matplotlib.cm as cm

# %%
cv = CountVectorizer(ngram_range=(1,1), stop_words='english', max_features=20)
counts_matrix = cv.fit_transform(pdf_data['Content'])

# %%
counts_matrix.shape
# Out:
# (21, 20)

# %%
# Get feature names (words)
words = cv.get_feature_names_out()

# Create co-occurrence matrix
co_occurrences = (counts_matrix.T * counts_matrix) 
co_occurrences.setdiag(0) # fill same word cooccurence to 0

# Create co-occurrence DataFrame
co_occurrences_df = pd.DataFrame(co_occurrences.todense(), index=words, columns=words)

# Create graph from the co-occurrence dataframe
G = nx.from_pandas_adjacency(co_occurrences_df)

# You may draw this graph using Networkx draw function or visualize using Gephi by exporting
# nx.write_gexf(G, 'co_occurrences.gexf')

# Draw the network
plt.figure(figsize=(10,10))
nx.draw_networkx(G, with_labels=True, node_size=20, node_color='blue')
plt.show()

# plt.savefig('word_co-occurrence.pdf', format='pdf')

# %%
# Get feature names (words)
words = cv.get_feature_names_out()

# Create co-occurrence matrix
co_occurrences = (counts_matrix.T * counts_matrix) 
co_occurrences.setdiag(0) # fill same word cooccurence to 0

# Create co-occurrence DataFrame
co_occurrences_df = pd.DataFrame(co_occurrences.todense(), index=words, columns=words)

# Create graph from the co-occurrence dataframe
G = nx.from_pandas_adjacency(co_occurrences_df)

for (u, v, wt) in G.edges.data('weight'):
    if wt is None:
        G[u][v]['weight'] = co_occurrences_df[u][v]

# Get edge weights for a list
weights = [G[u][v]['weight'] for u,v in G.edges]

# Normalize weights to range 0 to 1 for better visuals
weights = np.array(weights)
weights = (weights / weights.max()) * 5

# Set figure size for the plot
plt.figure(figsize=(10, 3))
plt.title('Top 20 words by co-occurrence frequency [Including "data"]', fontsize = 12)

# Draw nodes
pos = nx.kamada_kawai_layout(G)
nx.draw_networkx_nodes(G, pos, node_color='white', node_size=0)

# Draw edges with thickness representing the weight
nx.draw_networkx_edges(G, pos, width=weights, edge_color='grey')

# Draw node labels
nx.draw_networkx_labels(G, pos, font_size=12, font_color='red')

# Remove the spines (boundary) around the plot
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.gca().spines['left'].set_visible(False)

# plt.savefig('word_co-occurrence.pdf', format='pdf', bbox_inches='tight')
plt.show()
